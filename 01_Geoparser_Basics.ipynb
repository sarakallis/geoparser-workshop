# %% [markdown]
# # Irchel Geoparser Workshop: Getting Started with Geoparser
#
# This notebook is designed to help you explore and interact with the Geoparser library. By the end of this tutorial, you will have a solid understanding of how to use Geoparser for basic geoparsing tasks.
#
# **Objectives:**
#
# - Understand how to initialize and use Geoparser.
# - Perform geoparsing on text strings and documents.
# - Access and analyze geoparsing results.
# - Visualize locations on a map.
#
# ---
#
# ## 📖 **Documentation**
#
# This tutorial requires you to consult the Geoparser documentation: [docs.geoparser.app](https://docs.geoparser.app). Knowing where to find information about the library is crucial for working with it effectively, especially as it is likely that future updates may bring changes to functionality. The documentation will always be the definitive reference for how to use the package.
#
# ---
#
# ## 1. Geoparsing Text Strings <a name="geoparsing-text-strings"></a>
#
# Let's begin by geoparsing some simple text strings directly within this notebook.
#
# ### 1.1 Initialize Geoparser <a name="task-initialize-geoparser"></a>
#
# **Objective:** Initialize the Geoparser so that it's ready to parse text.
#
# **Instructions:**
#
# - Import the necessary class to use Geoparser.
# - Initialize an instance of the `Geoparser` class.
#
# By default, Geoparser uses the following configuration:
#
# geoparser = Geoparser(
#     spacy_model="en_core_web_sm",
#     transformer_model="dguzh/geo-all-MiniLM-L6-v2",
#     gazetteer="geonames"
# )
#
# These defaults prioritize speed over accuracy and are optimized for English texts. If you require higher accuracy and don’t mind increased computational cost, or need to process texts in other languages, you can specify different models as shown in the Advanced Usage section.

# %%
# To start using Geoparser, import it and create an instance of the Geoparser class:
from geoparser import Geoparser

# %%
geoparser = Geoparser()

# %% [markdown]
# ### 1.2 Geoparse a List of Strings <a name="task-geoparse-a-list-of-strings"></a>
#
# **Objective:** Use the Geoparser to parse a list of text strings.
#
# **Instructions:**
#
# - Use the example texts provided below.
# - Use the initialized Geoparser to parse these texts.
# - Store the results in a variable for further analysis.
#
# **Example Texts:**

# %%
texts = [
    "The University of Zurich, located in the heart of Zurich, Switzerland, is the largest university in Switzerland. It was founded in 1833 and has since become a leading institution in Europe.",
    "Researchers at the University of Zurich frequently collaborate with institutions in Germany, Belgium, Japan and Australia.",
    "The Botanical Garden of the University of Zurich is a popular attraction, featuring plants from regions like the Amazon rainforest and the Himalayas.",
    "Notable alumni include Albert Einstein, who later worked at the Institute for Advanced Study in Princeton, New Jersey.",
    "Students at the University of Zurich have the opportunity to study abroad in places like Tokyo, Sydney, and Cape Town."
]

# %% [markdown]
# **Your Code:**
#
# *(Write your code in the cell below.)*

# %%
docs = geoparser.parse(texts)
# Out:
# Toponym Recognition...
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Toponym Resolution...
# Batches:   0%|          | 0/23 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ### 1.3 Exploring Geoparsing Results <a name="exploring-geoparsing-results"></a>
#
# **Objective:** Understand and explore the structure of the results.
#
# Now that you've parsed the texts, let's explore the results. Geoparsed documents are stored in `GeoDoc` objects, which contain `GeoSpan` objects for each recognized toponym. Each `GeoSpan` represents a toponym and provides access to resolved location information.
#
# **Instructions:**
#
# - Iterate over the parsed documents:
#     - For each document:
#       - Print the original text.
#       - For each toponym found in the document:
#         - Print the toponym text.
#         - Access the resolved location information.
#         - Print some attributes of the resolved location.
#
# **Hints:**
#
# - Use `for` loops to iterate over the documents and toponyms.
# - Check if the `location` attribute of a toponym is valid (i.e. not `None`) before accessing its attributes.
#
# **Your Code:**
#
# *(Write your code in the cell below.)*

# %%
# Option 1. Iterate through the toponyms in a document to access the resolved locations:
for doc in docs:
    print(f"Document: {doc.text}")
    for toponym in doc.toponyms:
        print(f"- Toponym: {toponym.text}")
        location = toponym.location
        if location:
            print(f"  Resolved Location: {location['name']}, {location['country_name']}")
            print(f"  Feature Type: {location['feature_type']}")
            print(f"  Coordinates: ({location['latitude']}, {location['longitude']})")
            print(f"  Score: {toponym.score}")
        else:
            print("Location could not be resolved.")
    print()
# Out:
# Document: The University of Zurich, located in the heart of Zurich, Switzerland, is the largest university in Switzerland. It was founded in 1833 and has since become a leading institution in Europe.
# - Toponym: Zurich
#   Resolved Location: Zürich, Switzerland
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (47.36667, 8.55)
#   Score: 0.8428872227668762
# - Toponym: Switzerland
#   Resolved Location: Switzerland, Switzerland
#   Feature Type: independent political entity
#   Coordinates: (47.00016, 8.01427)
#   Score: 0.8402798175811768
# - Toponym: Switzerland
#   Resolved Location: Switzerland, Switzerland
#   Feature Type: independent political entity
#   Coordinates: (47.00016, 8.01427)
#   Score: 0.8402798175811768
# - Toponym: Europe
#   Resolved Location: Europe, None
#   Feature Type: continent
#   Coordinates: (48.69096, 9.14062)
#   Score: 0.7988290190696716
#
# Document: Researchers at the University of Zurich frequently collaborate with institutions in Germany, Belgium, Japan and Australia.
# - Toponym: Germany
#   Resolved Location: Federal Republic of Germany, Germany
#   Feature Type: independent political entity
#   Coordinates: (51.5, 10.5)
#   Score: 0.7318984270095825
# - Toponym: Belgium
#   Resolved Location: Kingdom of Belgium, Belgium
#   Feature Type: independent political entity
#   Coordinates: (50.75, 4.5)
#   Score: 0.7877693176269531
# - Toponym: Japan
#   Resolved Location: Japan, Japan
#   Feature Type: independent political entity
#   Coordinates: (35.68536, 139.75309)
#   Score: 0.7555059194564819
# - Toponym: Australia
#   Resolved Location: Commonwealth of Australia, Australia
#   Feature Type: independent political entity
#   Coordinates: (-25.0, 135.0)
#   Score: 0.7784268260002136
#
# Document: The Botanical Garden of the University of Zurich is a popular attraction, featuring plants from regions like the Amazon rainforest and the Himalayas.
#
# Document: Notable alumni include Albert Einstein, who later worked at the Institute for Advanced Study in Princeton, New Jersey.
# - Toponym: Princeton
#   Resolved Location: Princeton, United States
#   Feature Type: populated place
#   Coordinates: (40.34872, -74.65905)
#   Score: 0.7635065317153931
# - Toponym: New Jersey
#   Resolved Location: New Jersey, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.16706, -74.49987)
#   Score: 0.7971405982971191
#
# Document: Students at the University of Zurich have the opportunity to study abroad in places like Tokyo, Sydney, and Cape Town.
# - Toponym: Tokyo
#   Resolved Location: Tokyo, Japan
#   Feature Type: capital of a political entity
#   Coordinates: (35.6895, 139.69171)
#   Score: 0.5337133407592773
# - Toponym: Sydney
#   Resolved Location: Sydney, Australia
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (-33.86785, 151.20732)
#   Score: 0.6162893772125244
# - Toponym: Cape Town
#   Resolved Location: Cape Town, South Africa
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (-33.92584, 18.42322)
#   Score: 0.40701282024383545

# %%
# Option 2. When working with large datasets, it is recommended to access location data through the doc.locations property, which bundles the location retrieval of all toponyms within a document into a single database query:

for doc in docs:
    print(f"Document: {doc.text}")
    for toponym, location in zip(doc.toponyms, doc.locations):
        print(f"- Toponym: {toponym.text}")
        if location:
            print(f"  Resolved Location: {location['name']}, {location['country_name']}")
            print(f"  Feature Type: {location['feature_type']}")
            print(f"  Coordinates: ({location['latitude']}, {location['longitude']})")
            print(f"  Score: {toponym.score}")
        else:
            print("Location could not be resolved.")
    print()
# Out:
# Document: The University of Zurich, located in the heart of Zurich, Switzerland, is the largest university in Switzerland. It was founded in 1833 and has since become a leading institution in Europe.
# - Toponym: Zurich
#   Resolved Location: Zürich, Switzerland
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (47.36667, 8.55)
#   Score: 0.8428872227668762
# - Toponym: Switzerland
#   Resolved Location: Switzerland, Switzerland
#   Feature Type: independent political entity
#   Coordinates: (47.00016, 8.01427)
#   Score: 0.8402798175811768
# - Toponym: Switzerland
#   Resolved Location: Switzerland, Switzerland
#   Feature Type: independent political entity
#   Coordinates: (47.00016, 8.01427)
#   Score: 0.8402798175811768
# - Toponym: Europe
#   Resolved Location: Europe, None
#   Feature Type: continent
#   Coordinates: (48.69096, 9.14062)
#   Score: 0.7988290190696716
#
# Document: Researchers at the University of Zurich frequently collaborate with institutions in Germany, Belgium, Japan and Australia.
# - Toponym: Germany
#   Resolved Location: Federal Republic of Germany, Germany
#   Feature Type: independent political entity
#   Coordinates: (51.5, 10.5)
#   Score: 0.7318984270095825
# - Toponym: Belgium
#   Resolved Location: Kingdom of Belgium, Belgium
#   Feature Type: independent political entity
#   Coordinates: (50.75, 4.5)
#   Score: 0.7877693176269531
# - Toponym: Japan
#   Resolved Location: Japan, Japan
#   Feature Type: independent political entity
#   Coordinates: (35.68536, 139.75309)
#   Score: 0.7555059194564819
# - Toponym: Australia
#   Resolved Location: Commonwealth of Australia, Australia
#   Feature Type: independent political entity
#   Coordinates: (-25.0, 135.0)
#   Score: 0.7784268260002136
#
# Document: The Botanical Garden of the University of Zurich is a popular attraction, featuring plants from regions like the Amazon rainforest and the Himalayas.
#
# Document: Notable alumni include Albert Einstein, who later worked at the Institute for Advanced Study in Princeton, New Jersey.
# - Toponym: Princeton
#   Resolved Location: Princeton, United States
#   Feature Type: populated place
#   Coordinates: (40.34872, -74.65905)
#   Score: 0.7635065317153931
# - Toponym: New Jersey
#   Resolved Location: New Jersey, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.16706, -74.49987)
#   Score: 0.7971405982971191
#
# Document: Students at the University of Zurich have the opportunity to study abroad in places like Tokyo, Sydney, and Cape Town.
# - Toponym: Tokyo
#   Resolved Location: Tokyo, Japan
#   Feature Type: capital of a political entity
#   Coordinates: (35.6895, 139.69171)
#   Score: 0.5337133407592773
# - Toponym: Sydney
#   Resolved Location: Sydney, Australia
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (-33.86785, 151.20732)
#   Score: 0.6162893772125244
# - Toponym: Cape Town
#   Resolved Location: Cape Town, South Africa
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (-33.92584, 18.42322)
#   Score: 0.40701282024383545

# %% [markdown]
# Note that spaCy would, for example, recognise University of Zurich as an organization, not a location.

# %% [markdown]
# ---
#
# ## 2. Geoparsing Text Documents <a name="geoparsing-text-documents"></a>
#
# In this section, we'll work with actual text documents.
#
# ### 2.1 Loading Text Files <a name="loading-text-files"></a>
#
# **Objective:** Load text files from your `data` folder.
#
# **Instructions:**
#
# - Prepare some text files that you would like to geoparse.
#   - You can use your own documents or, for example, download text files from [this site](http://textfiles.com/wdirectory.html).
# - Store the `.txt` files in a dedicated `data` folder in your working directory.
# - Use the provided function `load_texts_from_directory` to load all `.txt` files from the `data` directory.
#
# **Prepared Code:**

# %%
import os
import re

# %%
def load_texts_from_directory(directory):
    texts = []
    filenames = []
    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            with open(os.path.join(directory, filename), 'r', encoding='utf-8') as file:
                text = file.read()
                # Replace newlines followed by a non-capitalized letter with a space
                text = re.sub(r'\n([a-z])', r' \1', text)
                texts.append(text)
                filenames.append(filename)
    return texts, filenames

# %%
# Load the texts
texts, filenames = load_texts_from_directory('data')

# %%
# Check loaded texts
for filename, text in zip(filenames, texts):
    print(f"{filename}: {len(text)} characters")
# Out:
# bbscase.txt: 11159 characters
# banned.txt: 15060 characters
# bandbook.txt: 6090 characters

# %% [markdown]
# ### 2.2 Geoparse Loaded Documents <a name="task-geoparse-loaded-documents"></a>
#
# **Objective:** Use Geoparser to parse the loaded text documents.
#
# **Instructions:**
#
# - Use the Geoparser to parse the list of texts you just loaded.
# - Store the results in a variable.
#
# **Your Code:**
#
# *(Write your code in the cell below.)*

# %%
# Geoparse the texts
docs = geoparser.parse(texts)
# Out:
# Toponym Recognition...
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Toponym Resolution...
# Batches:   0%|          | 0/473 [00:00<?, ?it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (344 > 256). Running this sequence through the model will result in indexing errors
# Batches:   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# ### 2.3 Analyzing Results <a name="analyzing-results"></a>
#
# **Objective:** Analyze the geoparsing results qualitatively.
#
# **Instructions:**
#
# - For each document:
#   - Print the filename.
#   - Print the number of toponyms found.
#   - List the toponyms and their resolved locations.
#   - For each resolved toponym, also print the similarity score.
#
# **Hints:**
#
#   - You can retrieve the sentence the toponym appears in using the `GeoSpan.sent.text` property.
#   - Use `for doc, filename in zip(docs, filenames)` to iterate through docs and filenames in parallel.
#
# **Analyze the Results:**
#
# - Qualitatively assess the results regarding toponym recognition and resolution.
# - Consider how the similarity score reflects the quality of the resolution.
#
# **Your Code:**
#
# *(Write your code in the cell below.)*

# %%
# - For each documen that we geoparsed above:
  #- Print the filename.
  #- Print the number of toponyms found.
  #- List the toponyms and their resolved locations.
  #- For each resolved toponym, also print the similarity score.

for filename, doc in zip(filenames, docs):
    print(f"Filename: {filename}")
    print(f"Number of Toponyms: {len(doc.toponyms)}")
    for toponym, location in zip(doc.toponyms, doc.locations):
        print(f"- Toponym: {toponym.text}")
        if location:
            print(f"  Resolved Location: {location['name']}, {location['country_name']}")
            print(f"  Feature Type: {location['feature_type']}")
            print(f"  Coordinates: ({location['latitude']}, {location['longitude']})")
            print(f"  Score: {toponym.score}")
        else:
            print("Location could not be resolved.")
    print()
# Out:
# Filename: bbscase.txt
# Number of Toponyms: 7
# - Toponym: Munroe
# Falls
#   Resolved Location: Munroe Falls, United States
#   Feature Type: populated place
#   Coordinates: (41.1445, -81.43983)
#   Score: 0.6490542888641357
# - Toponym: Summit County
#   Resolved Location: Summit County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (41.12598, -81.53217)
#   Score: 0.8736891746520996
# - Toponym: the
# City
#   Resolved Location: Thompsonville, United States
#   Feature Type: populated place
#   Coordinates: (41.99704, -72.59898)
#   Score: 0.6001893877983093
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.9630898237228394
# - Toponym: BBS'ing
# Location could not be resolved.
# - Toponym: Cleveland
#   Resolved Location: Cleveland, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (41.4995, -81.69541)
#   Score: 0.89790940284729
# - Toponym: OH
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.9065948724746704
#
# Filename: banned.txt
# Number of Toponyms: 211
# - Toponym: the United States
#   Resolved Location: Territories of the United States, United States
#   Feature Type: region
#   Coordinates: (35.27766, -102.35403)
#   Score: 0.7121752500534058
# - Toponym: Abingdon
#   Resolved Location: Abingdon, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (36.70983, -81.97735)
#   Score: 0.6465164422988892
# - Toponym: Virginia
#   Resolved Location: Virginia, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.54812, -77.44675)
#   Score: 0.885156512260437
# - Toponym: Elizabethton
#   Resolved Location: Elizabethton, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (36.34872, -82.21069)
#   Score: 0.6065858006477356
# - Toponym: Tennessee
#   Resolved Location: Tennessee, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.75035, -86.25027)
#   Score: 0.8868733644485474
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.8723214864730835
# - Toponym: Las Vegas
#   Resolved Location: Las Vegas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (36.17497, -115.13722)
#   Score: 0.8308025598526001
# - Toponym: Nevada
#   Resolved Location: Nevada, United States
#   Feature Type: first-order administrative division
#   Coordinates: (39.25021, -116.75119)
#   Score: 0.8625134229660034
# - Toponym: Vermont
#   Resolved Location: Vermont, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.00034, -72.74983)
#   Score: 0.788438081741333
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.8290572166442871
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.8196663856506348
# - Toponym: Michingan
# Location could not be resolved.
# - Toponym: North Jackson
#   Resolved Location: North Jackson, United States
#   Feature Type: populated place
#   Coordinates: (41.10006, -80.85731)
#   Score: 0.5894666314125061
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8534411787986755
# - Toponym: Anniston
#   Resolved Location: Anniston, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (33.65983, -85.83163)
#   Score: 0.45477670431137085
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.7874488830566406
# - Toponym: Montana
#   Resolved Location: Montana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.00025, -109.75102)
#   Score: 0.8421877026557922
# - Toponym: Strongsville
#   Resolved Location: Strongsville, United States
#   Feature Type: populated place
#   Coordinates: (41.3145, -81.83569)
#   Score: 0.6826931238174438
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8534411787986755
# - Toponym: Dallas
#   Resolved Location: Dallas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (32.78306, -96.80667)
#   Score: 0.7712880969047546
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.7704073190689087
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.8196663856506348
# - Toponym: Westport
#   Resolved Location: Westport, United States
#   Feature Type: populated place
#   Coordinates: (41.14149, -73.3579)
#   Score: 0.5368659496307373
# - Toponym: Rhode Island
#   Resolved Location: Rhode Island, United States
#   Feature Type: first-order administrative division
#   Coordinates: (41.75038, -71.49978)
#   Score: 0.7080686688423157
# - Toponym: Colorado
#   Resolved Location: Colorado, United States
#   Feature Type: first-order administrative division
#   Coordinates: (39.00027, -105.50083)
#   Score: 0.8363646268844604
# - Toponym: Anniston
#   Resolved Location: Anniston, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (33.65983, -85.83163)
#   Score: 0.45477670431137085
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.7874488830566406
# - Toponym: Oakland
#   Resolved Location: Oakland, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (37.80437, -122.2708)
#   Score: 0.8822669982910156
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.8246265649795532
# - Toponym: Hayward
#   Resolved Location: Hayward, United States
#   Feature Type: populated place
#   Coordinates: (37.66882, -122.0808)
#   Score: 0.7919392585754395
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.8246265649795532
# - Toponym: Harrisburg
#   Resolved Location: Harrisburg, United States
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (40.2737, -76.88442)
#   Score: 0.7398173213005066
# - Toponym: Washington County
#   Resolved Location: Washington County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (30.21453, -96.40344)
#   Score: 0.5682400465011597
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8773078918457031
# - Toponym: Rankin County
#   Resolved Location: Rankin County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (32.26412, -89.9458)
#   Score: 0.4665774703025818
# - Toponym: Mississippi
#   Resolved Location: Mississippi, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -89.75036)
#   Score: 0.7993955612182617
# - Toponym: School District
#   Resolved Location: Boykins Elementary School, United States
#   Feature Type: school
#   Coordinates: (36.5793, -77.21425)
#   Score: 0.4358447790145874
# - Toponym: Bradford
#   Resolved Location: Bradford, United States
#   Feature Type: populated place
#   Coordinates: (31.98877, -95.76663)
#   Score: 0.5980371236801147
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8097485303878784
# - Toponym: Hayward
#   Resolved Location: Hayward, United States
#   Feature Type: populated place
#   Coordinates: (37.66882, -122.0808)
#   Score: 0.5323476791381836
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.8072361946105957
# - Toponym: Dallas
#   Resolved Location: Dallas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (32.78306, -96.80667)
#   Score: 0.831774115562439
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.8226182460784912
# - Toponym: Vancouver
#   Resolved Location: Vancouver, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (45.63873, -122.66149)
#   Score: 0.6383546590805054
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.8257189989089966
# - Toponym: Wise County
#   Resolved Location: Wise County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (33.2159, -97.65445)
#   Score: 0.6661397814750671
# - Toponym: Virginia
#   Resolved Location: Virginia, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.54812, -77.44675)
#   Score: 0.8390353918075562
# - Toponym: Anniston
#   Resolved Location: Anniston, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (33.65983, -85.83163)
#   Score: 0.542344331741333
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8599327206611633
# - Toponym: Manitoba
#   Resolved Location: Manitoba, Canada
#   Feature Type: first-order administrative division
#   Coordinates: (55.00019, -97.00049)
#   Score: 0.7186331748962402
# - Toponym: Dallas
#   Resolved Location: Dallas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (32.78306, -96.80667)
#   Score: 0.8536471128463745
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.8561220169067383
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8439050912857056
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.45516520738601685
# - Toponym: Campbell County
#   Resolved Location: Campbell County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (44.24839, -105.54831)
#   Score: 0.5835670828819275
# - Toponym: Wyoming
#   Resolved Location: Wyoming, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00024, -107.5009)
#   Score: 0.885284423828125
# - Toponym: Plant City
#   Resolved Location: Plant City, United States
#   Feature Type: populated place
#   Coordinates: (28.01888, -82.11469)
#   Score: 0.524526834487915
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.8699884414672852
# - Toponym: Emporium
#   Resolved Location: Emporium, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (41.51145, -78.23529)
#   Score: 0.5421005487442017
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8206714391708374
# - Toponym: Arkansas
#   Resolved Location: Arkansas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (34.75037, -92.50044)
#   Score: 0.8720381259918213
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8538854718208313
# - Toponym: Richmond
#   Resolved Location: Richmond, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (37.74786, -84.29465)
#   Score: 0.6162928342819214
# - Toponym: Rhode Island
#   Resolved Location: Rhode Island, United States
#   Feature Type: first-order administrative division
#   Coordinates: (41.75038, -71.49978)
#   Score: 0.7780023813247681
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8172851800918579
# - Toponym: Orlando
#   Resolved Location: Orlando, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (28.53834, -81.37924)
#   Score: 0.8166662454605103
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.8537682294845581
# - Toponym: Akron
#   Resolved Location: Akron, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (41.08144, -81.51901)
#   Score: 0.7154051065444946
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8367136716842651
# - Toponym: School District
#   Resolved Location: Boykins Elementary School, United States
#   Feature Type: school
#   Coordinates: (36.5793, -77.21425)
#   Score: 0.5002396106719971
# - Toponym: Nebraska
#   Resolved Location: Nebraska, United States
#   Feature Type: first-order administrative division
#   Coordinates: (41.50028, -99.75067)
#   Score: 0.7763974070549011
# - Toponym: Cedar Rapids
#   Resolved Location: Cedar Rapids, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (42.00833, -91.64407)
#   Score: 0.6692923903465271
# - Toponym: Iowa
#   Resolved Location: Iowa, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.00027, -93.50049)
#   Score: 0.8621922731399536
# - Toponym: Patrick County
#   Resolved Location: Patrick County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (36.67833, -80.28435)
#   Score: 0.593082845211029
# - Toponym: Virginia
#   Resolved Location: Virginia, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.54812, -77.44675)
#   Score: 0.872046172618866
# - Toponym: Park Hill
#   Resolved Location: Hill Park, United States
#   Feature Type: park
#   Coordinates: (38.41602, -121.36162)
#   Score: 0.5685482025146484
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.7798153758049011
# - Toponym: Kanawha
#   Resolved Location: Charleston, United States
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (38.34982, -81.63262)
#   Score: 0.7467364072799683
# - Toponym: Iowa
#   Resolved Location: Iowa, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.00027, -93.50049)
#   Score: 0.8621922731399536
# - Toponym: Manitoba
#   Resolved Location: Manitoba, Canada
#   Feature Type: first-order administrative division
#   Coordinates: (55.00019, -97.00049)
#   Score: 0.7197430729866028
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8433343172073364
# - Toponym: School District
#   Resolved Location: Boykins Elementary School, United States
#   Feature Type: school
#   Coordinates: (36.5793, -77.21425)
#   Score: 0.5002396106719971
# - Toponym: Richford
#   Resolved Location: Richford, United States
#   Feature Type: populated place
#   Coordinates: (44.99699, -72.67124)
#   Score: 0.6046421527862549
# - Toponym: Vermonth
# Location could not be resolved.
# - Toponym: Xenia
#   Resolved Location: Xenia, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (39.68478, -83.92965)
#   Score: 0.703183650970459
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.846851110458374
# - Toponym: Winnetka
#   Resolved Location: Winnetka, United States
#   Feature Type: populated place
#   Coordinates: (42.10808, -87.7359)
#   Score: 0.6992329955101013
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.8664616346359253
# - Toponym: Warrington
#   Resolved Location: Warrington, United States
#   Feature Type: populated place
#   Coordinates: (39.61281, -87.93753)
#   Score: 0.5492167472839355
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8372985124588013
# - Toponym: Davenport
#   Resolved Location: Davenport, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (41.52364, -90.57764)
#   Score: 0.6368908882141113
# - Toponym: Iowa
#   Resolved Location: Iowa, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.00027, -93.50049)
#   Score: 0.8744310736656189
# - Toponym: Fairfax County
#   Resolved Location: Fairfax County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (38.83469, -77.27622)
#   Score: 0.5955962538719177
# - Toponym: Virginia
#   Resolved Location: Virginia, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.54812, -77.44675)
#   Score: 0.888836145401001
# - Toponym: Houston
#   Resolved Location: Houston, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (29.76328, -95.36327)
#   Score: 0.8143686652183533
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.8147212862968445
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8372985124588013
# - Toponym: Springfield
#   Resolved Location: Springfield, United States
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (39.80172, -89.64371)
#   Score: 0.6856123208999634
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.8664617538452148
# - Toponym: Waukegan
#   Resolved Location: Waukegan, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (42.36363, -87.84479)
#   Score: 0.6884109973907471
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.8664617538452148
# - Toponym: Caspar
#   Resolved Location: Caspar, United States
#   Feature Type: populated place
#   Coordinates: (39.3635, -123.81585)
#   Score: 0.49631011486053467
# - Toponym: Wyoming
#   Resolved Location: Wyoming, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00024, -107.5009)
#   Score: 0.8769259452819824
# - Toponym: Haywood County
#   Resolved Location: Haywood County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (35.58322, -89.28384)
#   Score: 0.5552225112915039
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.9041188955307007
# - Toponym: Widefield
#   Resolved Location: Widefield, United States
#   Feature Type: populated place
#   Coordinates: (38.73333, -104.71997)
#   Score: 0.3800197243690491
# - Toponym: Colorado
#   Resolved Location: Colorado, United States
#   Feature Type: first-order administrative division
#   Coordinates: (39.00027, -105.50083)
#   Score: 0.9079464077949524
# - Toponym: Vancouver
#   Resolved Location: Vancouver, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (45.63873, -122.66149)
#   Score: 0.6559292674064636
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.8275582790374756
# - Toponym: School District
#   Resolved Location: Boykins Elementary School, United States
#   Feature Type: school
#   Coordinates: (36.5793, -77.21425)
#   Score: 0.3598587214946747
# - Toponym: Gastonia
#   Resolved Location: Gastonia, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (35.26208, -81.1873)
#   Score: 0.5423981547355652
# - Toponym: North Carolina
#   Resolved Location: North Carolina, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.50069, -80.00032)
#   Score: 0.8873793482780457
# - Toponym: Dallas
#   Resolved Location: Dallas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (32.78306, -96.80667)
#   Score: 0.9490267038345337
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.9526159763336182
# - Toponym: South Dakota
#   Resolved Location: South Dakota, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.50026, -100.25069)
#   Score: 0.7925694584846497
# - Toponym: North Carolina
#   Resolved Location: North Carolina, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.50069, -80.00032)
#   Score: 0.8399505615234375
# - Toponym: Arizona
#   Resolved Location: Arizona, United States
#   Feature Type: first-order administrative division
#   Coordinates: (34.5003, -111.50098)
#   Score: 0.9138845205307007
# - Toponym: Olney
#   Resolved Location: Olney, United States
#   Feature Type: populated place
#   Coordinates: (33.37066, -98.75284)
#   Score: 0.6407672166824341
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.9526159763336182
# - Toponym: Vancouver
#   Resolved Location: Vancouver, Canada
#   Feature Type: populated place
#   Coordinates: (49.24966, -123.11934)
#   Score: 0.6308066248893738
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.8361684083938599
# - Toponym: Haines City
#   Resolved Location: Haines City, United States
#   Feature Type: populated place
#   Coordinates: (28.1145, -81.62009)
#   Score: 0.6105113625526428
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.903739333152771
# - Toponym: Midland
#   Resolved Location: Midland, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (31.99735, -102.07791)
#   Score: 0.8727090954780579
# - Toponym: Michigan
#   Resolved Location: Michigan, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.25029, -85.50033)
#   Score: 0.8480998277664185
# - Toponym: Jackson County
#   Resolved Location: Jackson County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (30.79539, -85.21546)
#   Score: 0.7565187215805054
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.8856287002563477
# - Toponym: Syracuse
#   Resolved Location: Syracuse, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (43.04812, -76.14742)
#   Score: 0.626386284828186
# - Toponym: Indiana
#   Resolved Location: Indiana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -86.25027)
#   Score: 0.8242073059082031
# - Toponym: Oil City
#   Resolved Location: Oil City, United States
#   Feature Type: populated place
#   Coordinates: (35.74699, -101.5135)
#   Score: 0.5549921989440918
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.829336941242218
# - Toponym: Grand Blanc
#   Resolved Location: Grand Blanc, United States
#   Feature Type: populated place
#   Coordinates: (42.92753, -83.62995)
#   Score: 0.45984986424446106
# - Toponym: Michigan
#   Resolved Location: Michigan, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.25029, -85.50033)
#   Score: 0.7989892959594727
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.7813732624053955
# - Toponym: Scottsboro
#   Resolved Location: Scottsboro, United States
#   Feature Type: populated place
#   Coordinates: (36.21061, -86.92778)
#   Score: 0.6692517995834351
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.7939745187759399
# - Toponym: Greenville
#   Resolved Location: Greeneville, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (36.16316, -82.83099)
#   Score: 0.6957015991210938
# - Toponym: South Carolina
#   Resolved Location: South Carolina, United States
#   Feature Type: first-order administrative division
#   Coordinates: (34.00043, -81.00009)
#   Score: 0.7785440683364868
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.814102292060852
# - Toponym: School District
#   Resolved Location: Boykins Elementary School, United States
#   Feature Type: school
#   Coordinates: (36.5793, -77.21425)
#   Score: 0.44341790676116943
# - Toponym: St. David
#   Resolved Location: Saint Davids, United Kingdom
#   Feature Type: populated place
#   Coordinates: (51.88094, -5.26554)
#   Score: 0.4789835214614868
# - Toponym: Arizona
#   Resolved Location: Arizona, United States
#   Feature Type: first-order administrative division
#   Coordinates: (34.5003, -111.50098)
#   Score: 0.8634576797485352
# - Toponym: Telly City
# Location could not be resolved.
# - Toponym: Indiana
#   Resolved Location: Indiana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -86.25027)
#   Score: 0.8242073059082031
# - Toponym: Knoxville
#   Resolved Location: Knoxville, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (35.96064, -83.92074)
#   Score: 0.8200962543487549
# - Toponym: Tennessee
#   Resolved Location: Tennessee, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.75035, -86.25027)
#   Score: 0.8776313066482544
# - Toponym: New Hampshire
#   Resolved Location: New Hampshire, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.66702, -71.4998)
#   Score: 0.8568099737167358
# - Toponym: New Jersey
#   Resolved Location: New Jersey, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.16706, -74.49987)
#   Score: 0.8613590002059937
# - Toponym: Omak
#   Resolved Location: Omak, United States
#   Feature Type: populated place
#   Coordinates: (48.41099, -119.52755)
#   Score: 0.46264705061912537
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.8242721557617188
# - Toponym: Buckland
#   Resolved Location: Buckland, United States
#   Feature Type: populated place
#   Coordinates: (41.79621, -72.55064)
#   Score: 0.5809823274612427
# - Toponym: Mass
#   Resolved Location: Massachusetts, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.36565, -71.10832)
#   Score: 0.7927738428115845
# - Toponym: Westport
#   Resolved Location: Westport, United States
#   Feature Type: populated place
#   Coordinates: (42.84175, -72.34759)
#   Score: 0.6961546540260315
# - Toponym: Massachusetts
#   Resolved Location: Massachusetts, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.36565, -71.10832)
#   Score: 0.792773962020874
# - Toponym: St. Anthony
#   Resolved Location: Saint Anthony, United States
#   Feature Type: populated place
#   Coordinates: (45.02052, -93.218)
#   Score: 0.5566887855529785
# - Toponym: Idaho
#   Resolved Location: Idaho, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.5002, -114.25118)
#   Score: 0.8116106986999512
# - Toponym: New Hampshire
#   Resolved Location: New Hampshire, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.66702, -71.4998)
#   Score: 0.8362689018249512
# - Toponym: New Hampshire
#   Resolved Location: New Hampshire, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.66702, -71.4998)
#   Score: 0.8362688422203064
# - Toponym: Whyoming
# Location could not be resolved.
# - Toponym: Hillsboro
#   Resolved Location: Hillsboro, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (38.23228, -90.5629)
#   Score: 0.7705322504043579
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.9041385054588318
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.4110856354236603
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.7665761709213257
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.4724617600440979
# - Toponym: Stroudsburg
#   Resolved Location: Stroudsburg, United States
#   Feature Type: populated place
#   Coordinates: (40.98676, -75.19462)
#   Score: 0.5435785055160522
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8129547834396362
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.7665761709213257
# - Toponym: Shippensburg
#   Resolved Location: Shippensburg, United States
#   Feature Type: populated place
#   Coordinates: (40.05065, -77.52026)
#   Score: 0.5658679008483887
# - Toponym: Campbell County
#   Resolved Location: Campbell County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (38.94648, -84.3797)
#   Score: 0.6484047174453735
# - Toponym: Wyoming
#   Resolved Location: Wyoming, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00024, -107.5009)
#   Score: 0.8855623006820679
# - Toponym: Washington County
#   Resolved Location: Washington County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (37.75338, -85.17475)
#   Score: 0.5630894899368286
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8393334150314331
# - Toponym: Anaheim
#   Resolved Location: Anaheim, United States
#   Feature Type: populated place
#   Coordinates: (33.83529, -117.9145)
#   Score: 0.4744996428489685
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.7874833941459656
# - Toponym: Drake
#   Resolved Location: Moats, United States
#   Feature Type: populated place
#   Coordinates: (41.33172, -84.52578)
#   Score: 0.6147806644439697
# - Toponym: North Carolina
#   Resolved Location: North Carolina, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.50069, -80.00032)
#   Score: 0.7332977056503296
# - Toponym: Rochester
#   Resolved Location: Brinkhaven, United States
#   Feature Type: populated place
#   Coordinates: (40.46951, -82.19405)
#   Score: 0.6181344985961914
# - Toponym: Michigan
#   Resolved Location: Michigan, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.25029, -85.50033)
#   Score: 0.8150247931480408
# - Toponym: Levittown
#   Resolved Location: Levittown, United States
#   Feature Type: populated place
#   Coordinates: (40.72593, -73.51429)
#   Score: 0.5298670530319214
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8097018003463745
# - Toponym: North Jackson
#   Resolved Location: North Jackson, United States
#   Feature Type: populated place
#   Coordinates: (41.10006, -80.85731)
#   Score: 0.5385072231292725
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.844662606716156
# - Toponym: Lakeland
#   Resolved Location: Lakeland, United States
#   Feature Type: populated place
#   Coordinates: (41.66005, -83.2577)
#   Score: 0.6260672807693481
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.8488940596580505
# - Toponym: Washington Park High School
#   Resolved Location: Park High School, United States
#   Feature Type: school
#   Coordinates: (42.71785, -87.80462)
#   Score: 0.5506728887557983
# - Toponym: Kentucky
#   Resolved Location: Kentucky, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.20042, -84.87762)
#   Score: 0.8700089454650879
# - Toponym: Caspar
#   Resolved Location: Caspar, United States
#   Feature Type: populated place
#   Coordinates: (39.3635, -123.81585)
#   Score: 0.3963243365287781
# - Toponym: Wyoming
#   Resolved Location: Wyoming, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00024, -107.5009)
#   Score: 0.8855623006820679
# - Toponym: Bozeman
#   Resolved Location: Bozeman, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (45.67965, -111.03856)
#   Score: 0.563331663608551
# - Toponym: Montana
#   Resolved Location: Montana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.00025, -109.75102)
#   Score: 0.8507771492004395
# - Toponym: Pagosa Springs
#   Resolved Location: Pagosa Springs, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (37.26945, -107.00976)
#   Score: 0.5601739287376404
# - Toponym: Colorado
#   Resolved Location: Colorado, United States
#   Feature Type: first-order administrative division
#   Coordinates: (39.00027, -105.50083)
#   Score: 0.8501368165016174
# - Toponym: Eden Valley
#   Resolved Location: Eden Valley, United States
#   Feature Type: None
#   Coordinates: (45.32361, -94.54361)
#   Score: 0.575458288192749
# - Toponym: Minnesota
#   Resolved Location: Minnesota, United States
#   Feature Type: first-order administrative division
#   Coordinates: (46.25024, -94.25055)
#   Score: 0.8332279920578003
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8120919466018677
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.42984887957572937
# - Toponym: Warren
#   Resolved Location: Warren, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (48.19664, -96.77284)
#   Score: 0.6906915307044983
# - Toponym: Indiana
#   Resolved Location: Indiana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -86.25027)
#   Score: 0.817644476890564
# - Toponym: Waukegan
#   Resolved Location: Waukegan, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (42.36363, -87.84479)
#   Score: 0.6249364614486694
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.7822775840759277
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.42984887957572937
# - Toponym: Kansas City
#   Resolved Location: Kansas City, United States
#   Feature Type: populated place
#   Coordinates: (39.09973, -94.57857)
#   Score: 0.6318057775497437
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.9058600664138794
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.9058600664138794
# - Toponym: Waukegan
#   Resolved Location: Waukegan, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (42.36363, -87.84479)
#   Score: 0.6629481315612793
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.8308368921279907
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.5064499974250793
# - Toponym: Minot
#   Resolved Location: Minot, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (48.23251, -101.29627)
#   Score: 0.5419343113899231
# - Toponym: North Dakota
#   Resolved Location: North Dakota, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50027, -100.00068)
#   Score: 0.8134435415267944
# - Toponym: Xenia
#   Resolved Location: Xenia, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (39.68478, -83.92965)
#   Score: 0.8168631792068481
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.9338366985321045
#
# Filename: bandbook.txt
# Number of Toponyms: 22
# - Toponym: Jr.
#   Resolved Location: Martial Billeaud Jr. House, United States
#   Feature Type: house(s)
#   Coordinates: (30.149, -91.96398)
#   Score: 0.45670604705810547
# - Toponym: Baldwin
#   Resolved Location: Baldwin, United States
#   Feature Type: populated place
#   Coordinates: (40.33813, -79.97894)
#   Score: 0.607940673828125
# - Toponym: Huxley
#   Resolved Location: Huxley, United States
#   Feature Type: populated place
#   Coordinates: (31.76239, -93.87713)
#   Score: 0.5207463502883911
# - Toponym: K Vonnegut
# Location could not be resolved.
# - Toponym: Choirboys
# Location could not be resolved.
# - Toponym: Deep Valley
#   Resolved Location: Deep Valley, United States
#   Feature Type: populated place
#   Coordinates: (39.33869, -80.84372)
#   Score: 0.5632370114326477
# - Toponym: Puerto Rican
#   Resolved Location: Spanish Virgin Islands, Puerto Rico
#   Feature Type: islands
#   Coordinates: (18.14259, -65.35629)
#   Score: 0.5146633386611938
# - Toponym: Baldwin
#   Resolved Location: Baldwin, United States
#   Feature Type: populated place
#   Coordinates: (40.33813, -79.97894)
#   Score: 0.6533857583999634
# - Toponym: J. Steibeck
# Location could not be resolved.
# - Toponym: Rollin
#   Resolved Location: Rollin, United States
#   Feature Type: None
#   Coordinates: (41.2618, -123.11726)
#   Score: 0.5178203582763672
# - Toponym: K Gilden
# Location could not be resolved.
# - Toponym: Cold Blood
# Location could not be resolved.
# - Toponym: Neufeld
#   Resolved Location: Neufeld, United States
#   Feature Type: populated place
#   Coordinates: (35.6194, -119.33261)
#   Score: 0.6094467639923096
# - Toponym: Bradbury
#   Resolved Location: Bradbury, United States
#   Feature Type: populated place
#   Coordinates: (34.14695, -117.9709)
#   Score: 0.6163761019706726
# - Toponym: Solzhenitayn
# Location could not be resolved.
# - Toponym: K Kesey
# Location could not be resolved.
# - Toponym: Bradford
#   Resolved Location: Bradford, United Kingdom
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (53.79391, -1.75206)
#   Score: 0.6706134080886841
# - Toponym: D. Jenkins
# Location could not be resolved.
# - Toponym: Knowles
#   Resolved Location: Knowles, United States
#   Feature Type: populated place
#   Coordinates: (36.87336, -100.19347)
#   Score: 0.5023531913757324
# - Toponym: W Faulkner
# Location could not be resolved.
# - Toponym: Baldwin
#   Resolved Location: Baldwin, United States
#   Feature Type: populated place
#   Coordinates: (40.33813, -79.97894)
#   Score: 0.6300956606864929
# - Toponym: K Vonnegut
# Location could not be resolved.

# %% [markdown]
# ### 2.4 Exploring Different Models <a name="task-exploring-different-models"></a>
#
# **Objective:** Explore how using different spaCy and transformer models affect the geoparsing results in terms of toponym recognition and resolution.
#
# **Instructions:**
#
# - Reinitialize Geoparser with different configurations.
# - Experiment with a different spaCy model (e.g. `en_core_web_trf`).
# - Experiment with a different transformer model (e.g. `dguzh/geo-all-distilroberta-v1`).
# - Compare the results (briefly).
#
# **Hints:**
#
# - You may need to install additional spaCy models if they are not already installed.
#
# **Note:** The suggested models are expected to be more accurate, but can also significantly increase runtimes when used for large collections of text.
#
# **Your Code:**
#
# *(Write your code in the cell below.)*

# %%
def geoparse_spacy(model, texts):
    #Define spaCy model
    geoparser = Geoparser(spacy_model= model) # e.g., "en_core_web_trf" or transformer_model="dguzh/geo-all-distilroberta-v1"

    # Parse the texts
    docs = geoparser.parse(texts)

    # Print results like above
    for filename, doc in zip(filenames, docs):
        print(f"Filename: {filename}")
        print(f"Number of Toponyms: {len(doc.toponyms)}")
        for toponym, location in zip(doc.toponyms, doc.locations):
            print(f"- Toponym: {toponym.text}")
            if location:
                print(f"  Resolved Location: {location['name']}, {location['country_name']}")
                print(f"  Feature Type: {location['feature_type']}")
                print(f"  Coordinates: ({location['latitude']}, {location['longitude']})")
                print(f"  Score: {toponym.score}")
            else:
                print("Location could not be resolved.")
        print()

# %%
geoparse_spacy("en_core_web_trf", texts)
# Out:
# Toponym Recognition...
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Toponym Resolution...
# Batches:   0%|          | 0/486 [00:00<?, ?it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (261 > 256). Running this sequence through the model will result in indexing errors
# Batches:   0%|          | 0/26 [00:00<?, ?it/s]
# Filename: bbscase.txt
# Number of Toponyms: 11
# - Toponym: Munroe
#   Resolved Location: Munroe Falls, United States
#   Feature Type: populated place
#   Coordinates: (41.1445, -81.43983)
#   Score: 0.6490542888641357
# - Toponym: Falls
#   Resolved Location: Falls County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (31.25327, -96.93585)
#   Score: 0.5819347500801086
# - Toponym: OH
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8684738874435425
# - Toponym: Munroe Falls
#   Resolved Location: Munroe Falls, United States
#   Feature Type: populated place
#   Coordinates: (41.1445, -81.43983)
#   Score: 0.6490542888641357
# - Toponym: Summit County
#   Resolved Location: Summit County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (41.12598, -81.53217)
#   Score: 0.8020797967910767
# - Toponym: Munroe Falls
#   Resolved Location: Munroe Falls, United States
#   Feature Type: populated place
#   Coordinates: (41.1445, -81.43983)
#   Score: 0.6418474912643433
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.9516375064849854
# - Toponym: Cleveland
#   Resolved Location: Cleveland, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (41.4995, -81.69541)
#   Score: 0.89790940284729
# - Toponym: OH
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.9065948724746704
# - Toponym: Munroe Falls
#   Resolved Location: Munroe Falls, United States
#   Feature Type: populated place
#   Coordinates: (41.1445, -81.43983)
#   Score: 0.5424952507019043
# - Toponym: OH
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.7374529242515564
#
# Filename: banned.txt
# Number of Toponyms: 196
# - Toponym: the United States
#   Resolved Location: Territories of the United States, United States
#   Feature Type: region
#   Coordinates: (35.27766, -102.35403)
#   Score: 0.6775542497634888
# - Toponym: Abingdon
#   Resolved Location: Abingdon, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (36.70983, -81.97735)
#   Score: 0.7071722149848938
# - Toponym: Virginia
#   Resolved Location: Virginia, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.54812, -77.44675)
#   Score: 0.9055611491203308
# - Toponym: Elizabethton
#   Resolved Location: Elizabethton, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (36.34872, -82.21069)
#   Score: 0.5653334259986877
# - Toponym: Tennessee
#   Resolved Location: Tennessee, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.75035, -86.25027)
#   Score: 0.882381021976471
# - Toponym: Miller
#   Resolved Location: Kismet, United States
#   Feature Type: populated place
#   Coordinates: (37.04717, -120.0935)
#   Score: 0.584663450717926
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.7540038228034973
# - Toponym: U.S.\
#   Resolved Location: United States, United States
#   Feature Type: independent political entity
#   Coordinates: (39.76, -98.5)
#   Score: 0.8179528117179871
# - Toponym: Las Vegas
#   Resolved Location: Las Vegas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (36.17497, -115.13722)
#   Score: 0.8957167863845825
# - Toponym: Nevada
#   Resolved Location: Nevada, United States
#   Feature Type: first-order administrative division
#   Coordinates: (39.25021, -116.75119)
#   Score: 0.9282057285308838
# - Toponym: Vergennes,\
#   Resolved Location: Vergennes, United States
#   Feature Type: populated place
#   Coordinates: (44.16728, -73.25401)
#   Score: 0.5597665309906006
# - Toponym: Vermont
#   Resolved Location: Vermont, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.00034, -72.74983)
#   Score: 0.8771408796310425
# - Toponym: DeFuniak Springs
#   Resolved Location: DeFuniak Springs, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (30.72102, -86.11522)
#   Score: 0.5729169845581055
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.8739252090454102
# - Toponym: Issaquah
#   Resolved Location: Issaquah, United States
#   Feature Type: populated place
#   Coordinates: (47.5301, -122.03262)
#   Score: 0.5051703453063965
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.845797061920166
# - Toponym: Middleville
#   Resolved Location: Middleville, United States
#   Feature Type: populated place
#   Coordinates: (39.31453, -80.19092)
#   Score: 0.5967750549316406
# - Toponym: Michingan
# Location could not be resolved.
# - Toponym: North Jackson
#   Resolved Location: North Jackson, United States
#   Feature Type: populated place
#   Coordinates: (41.10006, -80.85731)
#   Score: 0.4965396523475647
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8304998874664307
# - Toponym: Anniston
#   Resolved Location: Anniston, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (33.65983, -85.83163)
#   Score: 0.44789689779281616
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8211780190467834
# - Toponym: Strongsville
#   Resolved Location: Strongsville, United States
#   Feature Type: populated place
#   Coordinates: (41.3145, -81.83569)
#   Score: 0.6004164218902588
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8597952723503113
# - Toponym: Dallas
#   Resolved Location: Dallas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (32.78306, -96.80667)
#   Score: 0.8859206438064575
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.9017235040664673
# - Toponym: Snoqualmie
#   Resolved Location: Snoqualmie, United States
#   Feature Type: populated place
#   Coordinates: (47.52871, -121.82539)
#   Score: 0.5696229934692383
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.8549624085426331
# - Toponym: Westport
#   Resolved Location: Westport, United States
#   Feature Type: populated place
#   Coordinates: (41.14149, -73.3579)
#   Score: 0.5789282321929932
# - Toponym: Rhode Island
#   Resolved Location: Rhode Island, United States
#   Feature Type: first-order administrative division
#   Coordinates: (41.75038, -71.49978)
#   Score: 0.808317244052887
# - Toponym: Aurora
#   Resolved Location: Aurora, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (40.86723, -98.00422)
#   Score: 0.5690288543701172
# - Toponym: Colorado
#   Resolved Location: Colorado, United States
#   Feature Type: first-order administrative division
#   Coordinates: (39.00027, -105.50083)
#   Score: 0.8943825960159302
# - Toponym: Anniston
#   Resolved Location: Anniston, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (33.65983, -85.83163)
#   Score: 0.5000724196434021
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8704206943511963
# - Toponym: Oakland
#   Resolved Location: Oakland, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (37.80437, -122.2708)
#   Score: 0.8424432277679443
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.8990175724029541
# - Toponym: Hayward
#   Resolved Location: Hayward, United States
#   Feature Type: populated place
#   Coordinates: (37.66882, -122.0808)
#   Score: 0.6571788787841797
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.8990175724029541
# - Toponym: Harrisburg
#   Resolved Location: Harrisburg, United States
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (40.2737, -76.88442)
#   Score: 0.7569646835327148
# - Toponym: Washington County
#   Resolved Location: Washington County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (30.21453, -96.40344)
#   Score: 0.5821737051010132
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8927884101867676
# - Toponym: Rankin County
#   Resolved Location: Rankin County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (32.26412, -89.9458)
#   Score: 0.4744618535041809
# - Toponym: Mississippi
#   Resolved Location: Mississippi, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -89.75036)
#   Score: 0.826553463935852
# - Toponym: Bradford
#   Resolved Location: Bradford, United States
#   Feature Type: populated place
#   Coordinates: (31.98877, -95.76663)
#   Score: 0.6090993881225586
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8456637859344482
# - Toponym: Hayward
#   Resolved Location: Hayward, United States
#   Feature Type: populated place
#   Coordinates: (37.66882, -122.0808)
#   Score: 0.5636419653892517
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.8520704507827759
# - Toponym: French Lick
#   Resolved Location: Nashville, United States
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (36.16589, -86.78444)
#   Score: 0.7820445895195007
# - Toponym: Dallas
#   Resolved Location: Dallas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (32.78306, -96.80667)
#   Score: 0.8772186040878296
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.8701939582824707
# - Toponym: Vancouver
#   Resolved Location: Vancouver, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (45.63873, -122.66149)
#   Score: 0.6403346061706543
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.8491254448890686
# - Toponym: Wise County
#   Resolved Location: Wise County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (33.2159, -97.65445)
#   Score: 0.6756085157394409
# - Toponym: Virginia
#   Resolved Location: Virginia, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.54812, -77.44675)
#   Score: 0.8602640628814697
# - Toponym: Anniston
#   Resolved Location: Anniston, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (33.65983, -85.83163)
#   Score: 0.6103780269622803
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8927884101867676
# - Toponym: Morris
#   Resolved Location: Morris County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (33.11348, -94.73265)
#   Score: 0.7050265073776245
# - Toponym: Manitoba
#   Resolved Location: Manitoba, Canada
#   Feature Type: first-order administrative division
#   Coordinates: (55.00019, -97.00049)
#   Score: 0.6886930465698242
# - Toponym: Dallas
#   Resolved Location: Dallas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (32.78306, -96.80667)
#   Score: 0.8772186040878296
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.8701939582824707
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8456637859344482
# - Toponym: Campbell County
#   Resolved Location: Campbell County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (37.20564, -79.09635)
#   Score: 0.5486011505126953
# - Toponym: Wyoming
#   Resolved Location: Wyoming, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00024, -107.5009)
#   Score: 0.8514887094497681
# - Toponym: Plant City
#   Resolved Location: Plant City, United States
#   Feature Type: populated place
#   Coordinates: (32.85318, -85.19077)
#   Score: 0.48326459527015686
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.8532825708389282
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8231950402259827
# - Toponym: Scranton,\
#   Resolved Location: Scranton, United States
#   Feature Type: populated place
#   Coordinates: (32.30513, -99.10701)
#   Score: 0.6094774007797241
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8231950402259827
# - Toponym: Orlando
#   Resolved Location: Orlando, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (28.53834, -81.37924)
#   Score: 0.8077249526977539
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.8532825708389282
# - Toponym: Akron
#   Resolved Location: Akron, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (41.08144, -81.51901)
#   Score: 0.5668694972991943
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.7319816946983337
# - Toponym: Cedar Rapids
#   Resolved Location: Cedar Rapids, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (42.00833, -91.64407)
#   Score: 0.6125298738479614
# - Toponym: Iowa
#   Resolved Location: Iowa, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.00027, -93.50049)
#   Score: 0.8450127840042114
# - Toponym: Patrick County
#   Resolved Location: Patrick County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (36.67833, -80.28435)
#   Score: 0.5281644463539124
# - Toponym: Virginia
#   Resolved Location: Virginia, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.54812, -77.44675)
#   Score: 0.8602640628814697
# - Toponym: Park Hill
#   Resolved Location: Hill Park, United States
#   Feature Type: park
#   Coordinates: (26.20285, -97.70916)
#   Score: 0.6941612958908081
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.7576969861984253
# - Toponym: Kanawha
#   Resolved Location: Kanawha, United States
#   Feature Type: populated place
#   Coordinates: (33.8615, -95.25301)
#   Score: 0.6903510689735413
# - Toponym: Iowa
#   Resolved Location: Iowa, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.00027, -93.50049)
#   Score: 0.8450127840042114
# - Toponym: Morris
#   Resolved Location: Morris County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (33.11348, -94.73265)
#   Score: 0.7050265073776245
# - Toponym: Manitoba
#   Resolved Location: Manitoba, Canada
#   Feature Type: first-order administrative division
#   Coordinates: (55.00019, -97.00049)
#   Score: 0.6886930465698242
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8456637859344482
# - Toponym: Xenia
#   Resolved Location: Xenia, United States
#   Feature Type: populated place
#   Coordinates: (41.85693, -93.89328)
#   Score: 0.60024094581604
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.7319816946983337
# - Toponym: Winnetka
#   Resolved Location: Winnetka, United States
#   Feature Type: section of populated place
#   Coordinates: (34.21334, -118.57203)
#   Score: 0.620983898639679
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.7152369022369385
# - Toponym: Warrington
#   Resolved Location: Warrington, United Kingdom
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (53.39254, -2.58024)
#   Score: 0.5634194612503052
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8231950402259827
# - Toponym: Davenport
#   Resolved Location: Davenport, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (41.52364, -90.57764)
#   Score: 0.6042775511741638
# - Toponym: Iowa
#   Resolved Location: Iowa, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.00027, -93.50049)
#   Score: 0.8450127840042114
# - Toponym: Fairfax County
#   Resolved Location: Fairfax County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (38.83469, -77.27622)
#   Score: 0.5425876379013062
# - Toponym: Virginia
#   Resolved Location: Virginia, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.54812, -77.44675)
#   Score: 0.8602640628814697
# - Toponym: Houston
#   Resolved Location: Houston, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (29.76328, -95.36327)
#   Score: 0.8669048547744751
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.8701939582824707
# - Toponym: State College
#   Resolved Location: University Park, United States
#   Feature Type: populated place
#   Coordinates: (32.28343, -106.75334)
#   Score: 0.47905272245407104
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8231950402259827
# - Toponym: Springfield
#   Resolved Location: Springfield, United States
#   Feature Type: populated place
#   Coordinates: (31.98683, -95.80524)
#   Score: 0.6096521019935608
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.7152369022369385
# - Toponym: Waukegan
#   Resolved Location: Waukegan, United States
#   Feature Type: populated place
#   Coordinates: (30.30993, -95.33938)
#   Score: 0.6100059747695923
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.7152369022369385
# - Toponym: Caspar
#   Resolved Location: Caspar, United States
#   Feature Type: populated place
#   Coordinates: (39.3635, -123.81585)
#   Score: 0.4494274854660034
# - Toponym: Wyoming
#   Resolved Location: Wyoming, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00024, -107.5009)
#   Score: 0.8799395561218262
# - Toponym: Haywood County
#   Resolved Location: Haywood County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (35.55605, -82.98224)
#   Score: 0.6174014210700989
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.8654583692550659
# - Toponym: Vancouver
#   Resolved Location: Vancouver, Canada
#   Feature Type: populated place
#   Coordinates: (49.24966, -123.11934)
#   Score: 0.639185905456543
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.8137841820716858
# - Toponym: Gastonia
#   Resolved Location: Gastonia, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (35.26208, -81.1873)
#   Score: 0.6492997407913208
# - Toponym: North Carolina
#   Resolved Location: North Carolina, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.50069, -80.00032)
#   Score: 0.9177019000053406
# - Toponym: Dallas
#   Resolved Location: Dallas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (32.78306, -96.80667)
#   Score: 0.8891230821609497
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.8926118612289429
# - Toponym: Olney
#   Resolved Location: Olney, United States
#   Feature Type: populated place
#   Coordinates: (33.37066, -98.75284)
#   Score: 0.586247444152832
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.8926118612289429
# - Toponym: Vancouver
#   Resolved Location: Vancouver, Canada
#   Feature Type: populated place
#   Coordinates: (49.24966, -123.11934)
#   Score: 0.6308066248893738
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.8361684083938599
# - Toponym: Midland
#   Resolved Location: Midland, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (31.99735, -102.07791)
#   Score: 0.6921496391296387
# - Toponym: Michigan
#   Resolved Location: Michigan, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.25029, -85.50033)
#   Score: 0.9198873043060303
# - Toponym: Jackson County
#   Resolved Location: Jackson County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (42.24849, -84.42344)
#   Score: 0.5586174130439758
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.9210928678512573
# - Toponym: Syracuse
#   Resolved Location: Syracuse, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (43.04812, -76.14742)
#   Score: 0.6366816759109497
# - Toponym: Indiana
#   Resolved Location: Indiana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -86.25027)
#   Score: 0.8394030332565308
# - Toponym: Oil City
#   Resolved Location: Oil City, United States
#   Feature Type: populated place
#   Coordinates: (35.74699, -101.5135)
#   Score: 0.5634202361106873
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8467116951942444
# - Toponym: Grand Blanc
#   Resolved Location: Grand Blanc, United States
#   Feature Type: populated place
#   Coordinates: (42.92753, -83.62995)
#   Score: 0.47037795186042786
# - Toponym: Michigan
#   Resolved Location: Michigan, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.25029, -85.50033)
#   Score: 0.8196840286254883
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.805370032787323
# - Toponym: Scottsboro
#   Resolved Location: Scottsboro, United States
#   Feature Type: populated place
#   Coordinates: (36.21061, -86.92778)
#   Score: 0.6614295244216919
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8079622387886047
# - Toponym: Greenville
#   Resolved Location: Greeneville, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (36.16316, -82.83099)
#   Score: 0.689316987991333
# - Toponym: South Carolina
#   Resolved Location: South Carolina, United States
#   Feature Type: first-order administrative division
#   Coordinates: (34.00043, -81.00009)
#   Score: 0.7920624613761902
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.837260901927948
# - Toponym: St. David
#   Resolved Location: St. David's, United Kingdom
#   Feature Type: mall
#   Coordinates: (51.48083, -3.17576)
#   Score: 0.4766920804977417
# - Toponym: Arizona
#   Resolved Location: Arizona, United States
#   Feature Type: first-order administrative division
#   Coordinates: (34.5003, -111.50098)
#   Score: 0.8800103068351746
# - Toponym: Telly City
# Location could not be resolved.
# - Toponym: Indiana
#   Resolved Location: Indiana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -86.25027)
#   Score: 0.8394030332565308
# - Toponym: Knoxville
#   Resolved Location: Knoxville, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (35.96064, -83.92074)
#   Score: 0.8228193521499634
# - Toponym: Tennessee
#   Resolved Location: Tennessee, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.75035, -86.25027)
#   Score: 0.8903152942657471
# - Toponym: Mahwah
#   Resolved Location: Mahwah, United States
#   Feature Type: populated place
#   Coordinates: (41.08871, -74.14376)
#   Score: 0.6091572046279907
# - Toponym: New Jersey
#   Resolved Location: New Jersey, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.16706, -74.49987)
#   Score: 0.8729138374328613
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.8300156593322754
# - Toponym: Buckland
#   Resolved Location: Buckland, United States
#   Feature Type: populated place
#   Coordinates: (41.79621, -72.55064)
#   Score: 0.591407835483551
# - Toponym: Mass
#   Resolved Location: Massachusetts, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.36565, -71.10832)
#   Score: 0.8147993087768555
# - Toponym: Westport
#   Resolved Location: Westport, United States
#   Feature Type: populated place
#   Coordinates: (42.84175, -72.34759)
#   Score: 0.6955369114875793
# - Toponym: Massachusetts
#   Resolved Location: Massachusetts, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.36565, -71.10832)
#   Score: 0.8147993087768555
# - Toponym: St. Anthony
#   Resolved Location: Saint Anthony, United States
#   Feature Type: populated place
#   Coordinates: (45.02052, -93.218)
#   Score: 0.5590514540672302
# - Toponym: Idaho
#   Resolved Location: Idaho, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.5002, -114.25118)
#   Score: 0.8322118520736694
# - Toponym: Hillsboro
#   Resolved Location: Hillsboro, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (38.23228, -90.5629)
#   Score: 0.7661213874816895
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.9048779606819153
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8007360696792603
# - Toponym: Stroudsburg
#   Resolved Location: Stroudsburg, United States
#   Feature Type: populated place
#   Coordinates: (40.98676, -75.19462)
#   Score: 0.37595927715301514
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.7865721583366394
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8883122205734253
# - Toponym: Shippensburg
#   Resolved Location: Shippensburg, United States
#   Feature Type: populated place
#   Coordinates: (40.05065, -77.52026)
#   Score: 0.3973464369773865
# - Toponym: Pa
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8557464480400085
# - Toponym: Campbell County
#   Resolved Location: Campbell County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (38.94648, -84.3797)
#   Score: 0.5968939065933228
# - Toponym: Wyoming
#   Resolved Location: Wyoming, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00024, -107.5009)
#   Score: 0.9164789915084839
# - Toponym: Washington County
#   Resolved Location: Washington County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (37.75338, -85.17475)
#   Score: 0.4861662983894348
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8908796906471252
# - Toponym: Anaheim
#   Resolved Location: Anaheim, United States
#   Feature Type: populated place
#   Coordinates: (33.83529, -117.9145)
#   Score: 0.582301139831543
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.8912150859832764
# - Toponym: Drake
#   Resolved Location: Moats, United States
#   Feature Type: populated place
#   Coordinates: (41.33172, -84.52578)
#   Score: 0.6084079146385193
# - Toponym: North Carolina
#   Resolved Location: North Carolina, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.50069, -80.00032)
#   Score: 0.8233156800270081
# - Toponym: Rochester
#   Resolved Location: Rochester, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (44.02163, -92.4699)
#   Score: 0.6582735776901245
# - Toponym: Michigan
#   Resolved Location: Michigan, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.25029, -85.50033)
#   Score: 0.8637204170227051
# - Toponym: Levittown
#   Resolved Location: Levittown, United States
#   Feature Type: populated place
#   Coordinates: (40.72593, -73.51429)
#   Score: 0.5345368385314941
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8883122205734253
# - Toponym: North Jackson
#   Resolved Location: North Jackson, United States
#   Feature Type: populated place
#   Coordinates: (41.10006, -80.85731)
#   Score: 0.49492838978767395
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8721712827682495
# - Toponym: Lakeland
#   Resolved Location: Lakeland, United States
#   Feature Type: populated place
#   Coordinates: (41.66005, -83.2577)
#   Score: 0.6170997619628906
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.9072933197021484
# - Toponym: Racine
#   Resolved Location: Racine, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (42.72613, -87.78285)
#   Score: 0.6807597279548645
# - Toponym: Wi
#   Resolved Location: Wisconsin, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.50024, -90.00041)
#   Score: 0.8714438080787659
# - Toponym: Owensboro
#   Resolved Location: Owensboro, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (37.77422, -87.11333)
#   Score: 0.6549133062362671
# - Toponym: Kentucky
#   Resolved Location: Kentucky, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.20042, -84.87762)
#   Score: 0.8907722234725952
# - Toponym: Caspar
#   Resolved Location: Caspar, United States
#   Feature Type: populated place
#   Coordinates: (39.3635, -123.81585)
#   Score: 0.3667720854282379
# - Toponym: Wyoming
#   Resolved Location: Wyoming, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00024, -107.5009)
#   Score: 0.8130426406860352
# - Toponym: Bozeman
#   Resolved Location: Bozeman, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (45.67965, -111.03856)
#   Score: 0.7948669195175171
# - Toponym: Montana
#   Resolved Location: Montana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.00025, -109.75102)
#   Score: 0.8011351823806763
# - Toponym: Pagosa Springs
#   Resolved Location: Pagosa Springs, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (37.26945, -107.00976)
#   Score: 0.4898131787776947
# - Toponym: Colorado
#   Resolved Location: Colorado, United States
#   Feature Type: first-order administrative division
#   Coordinates: (39.00027, -105.50083)
#   Score: 0.8031197786331177
# - Toponym: Eden Valley
#   Resolved Location: Eden Valley, United States
#   Feature Type: None
#   Coordinates: (45.32361, -94.54361)
#   Score: 0.5120044350624084
# - Toponym: Minnesota
#   Resolved Location: Minnesota, United States
#   Feature Type: first-order administrative division
#   Coordinates: (46.25024, -94.25055)
#   Score: 0.7839006781578064
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.7843351364135742
# - Toponym: Warren
#   Resolved Location: Warren County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (38.76462, -91.16069)
#   Score: 0.668347954750061
# - Toponym: Indiana
#   Resolved Location: Indiana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -86.25027)
#   Score: 0.8069998025894165
# - Toponym: Waukegan
#   Resolved Location: Waukegan, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (42.36363, -87.84479)
#   Score: 0.7138857245445251
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.8172123432159424
# - Toponym: Kansas City
#   Resolved Location: Kansas City, United States
#   Feature Type: populated place
#   Coordinates: (39.09973, -94.57857)
#   Score: 0.6822271347045898
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.9156927466392517
# - Toponym: Casa Grande
#   Resolved Location: William Curry and Olive Price Holden House, United States
#   Feature Type: building(s)
#   Coordinates: (33.5762, -101.88211)
#   Score: 0.4984865188598633
# - Toponym: Waukegan
#   Resolved Location: Waukegan, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (42.36363, -87.84479)
#   Score: 0.7138857245445251
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.8172123432159424
# - Toponym: Minot
#   Resolved Location: Minot, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (48.23251, -101.29627)
#   Score: 0.5348684787750244
# - Toponym: North Dakota
#   Resolved Location: North Dakota, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50027, -100.00068)
#   Score: 0.7807779312133789
# - Toponym: Xenia
#   Resolved Location: Xenia, United States
#   Feature Type: populated place
#   Coordinates: (37.99531, -94.98636)
#   Score: 0.6668769121170044
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.671195387840271
#
# Filename: bandbook.txt
# Number of Toponyms: 1
# - Toponym: Andersonville
#   Resolved Location: Andersonville, United States
#   Feature Type: section of populated place
#   Coordinates: (41.97985, -87.66786)
#   Score: 0.5310127139091492

# %%
def geoparse_transformer(model, texts):
    #Define spaCy model
    geoparser = Geoparser(transformer_model= model) #  "dguzh/geo-all-distilroberta-v1"

    # Parse the texts
    docs = geoparser.parse(texts)

    # Print results like above
    for filename, doc in zip(filenames, docs):
        print(f"Filename: {filename}")
        print(f"Number of Toponyms: {len(doc.toponyms)}")
        for toponym, location in zip(doc.toponyms, doc.locations):
            print(f"- Toponym: {toponym.text}")
            if location:
                print(f"  Resolved Location: {location['name']}, {location['country_name']}")
                print(f"  Feature Type: {location['feature_type']}")
                print(f"  Coordinates: ({location['latitude']}, {location['longitude']})")
                print(f"  Score: {toponym.score}")
            else:
                print("Location could not be resolved.")
        print()

# %%
geoparse_transformer("dguzh/geo-all-distilroberta-v1", texts)
# Out:
# Toponym Recognition...
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Toponym Resolution...
# Batches:   0%|          | 0/473 [00:00<?, ?it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (573 > 512). Running this sequence through the model will result in indexing errors
# Batches:   0%|          | 0/30 [00:00<?, ?it/s]
# Filename: bbscase.txt
# Number of Toponyms: 7
# - Toponym: Munroe
# Falls
#   Resolved Location: Munroe Falls, United States
#   Feature Type: populated place
#   Coordinates: (41.1445, -81.43983)
#   Score: 0.68886798620224
# - Toponym: Summit County
#   Resolved Location: Summit County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (41.12598, -81.53217)
#   Score: 0.8035531044006348
# - Toponym: the
# City
#   Resolved Location: Sherman, United States
#   Feature Type: populated place
#   Coordinates: (41.57926, -73.49568)
#   Score: 0.5464845895767212
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.9667490720748901
# - Toponym: BBS'ing
# Location could not be resolved.
# - Toponym: Cleveland
#   Resolved Location: Cleveland, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (41.4995, -81.69541)
#   Score: 0.8633217215538025
# - Toponym: OH
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.9724416136741638
#
# Filename: banned.txt
# Number of Toponyms: 211
# - Toponym: the United States
#   Resolved Location: Territories of the United States, United States
#   Feature Type: region
#   Coordinates: (35.27766, -102.35403)
#   Score: 0.6799028515815735
# - Toponym: Abingdon
#   Resolved Location: Abingdon, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (36.70983, -81.97735)
#   Score: 0.594322919845581
# - Toponym: Virginia
#   Resolved Location: Virginia, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.54812, -77.44675)
#   Score: 0.9123780727386475
# - Toponym: Elizabethton
#   Resolved Location: Elizabethton, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (36.34872, -82.21069)
#   Score: 0.6593893766403198
# - Toponym: Tennessee
#   Resolved Location: Tennessee, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.75035, -86.25027)
#   Score: 0.9429099559783936
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.861858069896698
# - Toponym: Las Vegas
#   Resolved Location: Las Vegas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (36.17497, -115.13722)
#   Score: 0.8801904320716858
# - Toponym: Nevada
#   Resolved Location: Nevada, United States
#   Feature Type: first-order administrative division
#   Coordinates: (39.25021, -116.75119)
#   Score: 0.8742753863334656
# - Toponym: Vermont
#   Resolved Location: Vermont, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.00034, -72.74983)
#   Score: 0.8829518556594849
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.8886764049530029
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.7631169557571411
# - Toponym: Michingan
# Location could not be resolved.
# - Toponym: North Jackson
#   Resolved Location: North Jackson Station, United States
#   Feature Type: None
#   Coordinates: (41.10006, -80.87175)
#   Score: 0.5257716774940491
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.9032666087150574
# - Toponym: Anniston
#   Resolved Location: Anniston, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (33.65983, -85.83163)
#   Score: 0.47465676069259644
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8223037123680115
# - Toponym: Montana
#   Resolved Location: Montana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.00025, -109.75102)
#   Score: 0.8815996646881104
# - Toponym: Strongsville
#   Resolved Location: Strongsville, United States
#   Feature Type: populated place
#   Coordinates: (41.3145, -81.83569)
#   Score: 0.6588843464851379
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.9032666087150574
# - Toponym: Dallas
#   Resolved Location: Dallas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (32.78306, -96.80667)
#   Score: 0.8919511437416077
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.8557451963424683
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.7631169557571411
# - Toponym: Westport
#   Resolved Location: Westport, United States
#   Feature Type: populated place
#   Coordinates: (41.14149, -73.3579)
#   Score: 0.5425193309783936
# - Toponym: Rhode Island
#   Resolved Location: Rhode Island, United States
#   Feature Type: first-order administrative division
#   Coordinates: (41.75038, -71.49978)
#   Score: 0.7826440334320068
# - Toponym: Colorado
#   Resolved Location: Colorado, United States
#   Feature Type: first-order administrative division
#   Coordinates: (39.00027, -105.50083)
#   Score: 0.9249709844589233
# - Toponym: Anniston
#   Resolved Location: Anniston, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (33.65983, -85.83163)
#   Score: 0.47465676069259644
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8223037123680115
# - Toponym: Oakland
#   Resolved Location: Oakland, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (37.80437, -122.2708)
#   Score: 0.8930999636650085
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.9220818281173706
# - Toponym: Hayward
#   Resolved Location: Hayward, United States
#   Feature Type: populated place
#   Coordinates: (37.66882, -122.0808)
#   Score: 0.6676444411277771
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.9220818281173706
# - Toponym: Harrisburg
#   Resolved Location: Harrisburg, United States
#   Feature Type: populated place
#   Coordinates: (29.71828, -95.27966)
#   Score: 0.7317110300064087
# - Toponym: Washington County
#   Resolved Location: Washington County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (30.21453, -96.40344)
#   Score: 0.5914433002471924
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8412383794784546
# - Toponym: Rankin County
#   Resolved Location: Rankin County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (32.26412, -89.9458)
#   Score: 0.4283701181411743
# - Toponym: Mississippi
#   Resolved Location: Mississippi, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -89.75036)
#   Score: 0.8146191835403442
# - Toponym: School District
#   Resolved Location: Boykins Elementary School, United States
#   Feature Type: school
#   Coordinates: (36.5793, -77.21425)
#   Score: 0.3625375032424927
# - Toponym: Bradford
#   Resolved Location: Bradford, United States
#   Feature Type: populated place
#   Coordinates: (31.98877, -95.76663)
#   Score: 0.5920615792274475
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.845325231552124
# - Toponym: Hayward
#   Resolved Location: Hayward, United States
#   Feature Type: populated place
#   Coordinates: (37.66882, -122.0808)
#   Score: 0.6676444411277771
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.9220818281173706
# - Toponym: Dallas
#   Resolved Location: Dallas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (32.78306, -96.80667)
#   Score: 0.9104267358779907
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.9001980423927307
# - Toponym: Vancouver
#   Resolved Location: Vancouver, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (45.63873, -122.66149)
#   Score: 0.5976272821426392
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50012, -120.50147)
#   Score: 0.7562417387962341
# - Toponym: Wise County
#   Resolved Location: Wise County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (33.2159, -97.65445)
#   Score: 0.7046595811843872
# - Toponym: Virginia
#   Resolved Location: Virginia, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.54812, -77.44675)
#   Score: 0.8670251369476318
# - Toponym: Anniston
#   Resolved Location: Anniston, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (33.65983, -85.83163)
#   Score: 0.5739035606384277
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8924692869186401
# - Toponym: Manitoba
#   Resolved Location: Manitoba, Canada
#   Feature Type: first-order administrative division
#   Coordinates: (55.00019, -97.00049)
#   Score: 0.6976504325866699
# - Toponym: Dallas
#   Resolved Location: Dallas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (32.78306, -96.80667)
#   Score: 0.8840221166610718
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.8515664339065552
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8148295879364014
# - Toponym: School District
#   Resolved Location: Boykins Elementary School, United States
#   Feature Type: school
#   Coordinates: (36.5793, -77.21425)
#   Score: 0.4094373285770416
# - Toponym: Campbell County
#   Resolved Location: Campbell County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (37.20564, -79.09635)
#   Score: 0.5746161937713623
# - Toponym: Wyoming
#   Resolved Location: Wyoming, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00024, -107.5009)
#   Score: 0.8944774270057678
# - Toponym: Plant City
#   Resolved Location: Plant City, United States
#   Feature Type: populated place
#   Coordinates: (32.85318, -85.19077)
#   Score: 0.37979942560195923
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.8769045472145081
# - Toponym: Emporium
#   Resolved Location: Emporium, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (41.51145, -78.23529)
#   Score: 0.5398327112197876
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8474149107933044
# - Toponym: Arkansas
#   Resolved Location: Arkansas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (34.75037, -92.50044)
#   Score: 0.9211940765380859
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8503010272979736
# - Toponym: Richmond
#   Resolved Location: Richmond, United States
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (37.55376, -77.46026)
#   Score: 0.697759747505188
# - Toponym: Rhode Island
#   Resolved Location: Rhode Island, United States
#   Feature Type: first-order administrative division
#   Coordinates: (41.75038, -71.49978)
#   Score: 0.7601568698883057
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8842328190803528
# - Toponym: Orlando
#   Resolved Location: Orlando, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (28.53834, -81.37924)
#   Score: 0.8822311162948608
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.9014173150062561
# - Toponym: Akron
#   Resolved Location: Akron, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (41.08144, -81.51901)
#   Score: 0.6537381410598755
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8836113214492798
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.43187838792800903
# - Toponym: Nebraska
#   Resolved Location: Nebraska, United States
#   Feature Type: first-order administrative division
#   Coordinates: (41.50028, -99.75067)
#   Score: 0.8774079084396362
# - Toponym: Cedar Rapids
#   Resolved Location: Cedar Rapids, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (42.00833, -91.64407)
#   Score: 0.6891254186630249
# - Toponym: Iowa
#   Resolved Location: Iowa, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.00027, -93.50049)
#   Score: 0.8984032869338989
# - Toponym: Patrick County
#   Resolved Location: Patrick County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (36.67833, -80.28435)
#   Score: 0.55803382396698
# - Toponym: Virginia
#   Resolved Location: Virginia, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.54812, -77.44675)
#   Score: 0.8809744119644165
# - Toponym: Park Hill
#   Resolved Location: Park Hill, United States
#   Feature Type: section of populated place
#   Coordinates: (42.15753, -88.09591)
#   Score: 0.5545819401741028
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.870273768901825
# - Toponym: Kanawha
#   Resolved Location: Charleston, United States
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (38.34982, -81.63262)
#   Score: 0.752137303352356
# - Toponym: Iowa
#   Resolved Location: Iowa, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.00027, -93.50049)
#   Score: 0.8984032869338989
# - Toponym: Manitoba
#   Resolved Location: Manitoba, Canada
#   Feature Type: first-order administrative division
#   Coordinates: (55.00019, -97.00049)
#   Score: 0.7246354222297668
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8432053327560425
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.43187838792800903
# - Toponym: Richford
#   Resolved Location: Richford, United States
#   Feature Type: populated place
#   Coordinates: (44.02359, -89.4354)
#   Score: 0.5632100105285645
# - Toponym: Vermonth
# Location could not be resolved.
# - Toponym: Xenia
#   Resolved Location: Xenia, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (39.68478, -83.92965)
#   Score: 0.6482401490211487
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8840823769569397
# - Toponym: Winnetka
#   Resolved Location: Winnetka, United States
#   Feature Type: populated place
#   Coordinates: (42.10808, -87.7359)
#   Score: 0.6627469062805176
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.9368418455123901
# - Toponym: Warrington
#   Resolved Location: Warrington, United States
#   Feature Type: populated place
#   Coordinates: (39.61281, -87.93753)
#   Score: 0.6182848215103149
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8982131481170654
# - Toponym: Davenport
#   Resolved Location: Davenport, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (41.52364, -90.57764)
#   Score: 0.5949797630310059
# - Toponym: Iowa
#   Resolved Location: Iowa, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.00027, -93.50049)
#   Score: 0.8764795660972595
# - Toponym: Fairfax County
#   Resolved Location: Fairfax County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (38.83469, -77.27622)
#   Score: 0.5004542469978333
# - Toponym: Virginia
#   Resolved Location: Virginia, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.54812, -77.44675)
#   Score: 0.8709150552749634
# - Toponym: Houston
#   Resolved Location: Houston, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (29.76328, -95.36327)
#   Score: 0.8878829479217529
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.822672963142395
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8982131481170654
# - Toponym: Springfield
#   Resolved Location: Springfield, United States
#   Feature Type: seat of a first-order administrative division
#   Coordinates: (39.80172, -89.64371)
#   Score: 0.6359065771102905
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.9368418455123901
# - Toponym: Waukegan
#   Resolved Location: Waukegan, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (42.36363, -87.84479)
#   Score: 0.7940846681594849
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.9368418455123901
# - Toponym: Caspar
#   Resolved Location: Caspar, United States
#   Feature Type: populated place
#   Coordinates: (39.3635, -123.81585)
#   Score: 0.43111807107925415
# - Toponym: Wyoming
#   Resolved Location: Wyoming, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00024, -107.5009)
#   Score: 0.8076919913291931
# - Toponym: Haywood County
#   Resolved Location: Haywood County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (35.55605, -82.98224)
#   Score: 0.6552125215530396
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.855832040309906
# - Toponym: Widefield
#   Resolved Location: Widefield, United States
#   Feature Type: populated place
#   Coordinates: (38.73333, -104.71997)
#   Score: 0.4022674262523651
# - Toponym: Colorado
#   Resolved Location: Colorado, United States
#   Feature Type: first-order administrative division
#   Coordinates: (39.00027, -105.50083)
#   Score: 0.8691118359565735
# - Toponym: Vancouver
#   Resolved Location: Vancouver, Canada
#   Feature Type: populated place
#   Coordinates: (49.24966, -123.11934)
#   Score: 0.624927282333374
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: capital of a political entity
#   Coordinates: (38.89511, -77.03637)
#   Score: 0.7589704990386963
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.47846001386642456
# - Toponym: Gastonia
#   Resolved Location: Gastonia, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (35.26208, -81.1873)
#   Score: 0.7134190797805786
# - Toponym: North Carolina
#   Resolved Location: North Carolina, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.50069, -80.00032)
#   Score: 0.9267535209655762
# - Toponym: Dallas
#   Resolved Location: Dallas, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (32.78306, -96.80667)
#   Score: 0.9097473621368408
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.8750443458557129
# - Toponym: South Dakota
#   Resolved Location: South Dakota, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.50026, -100.25069)
#   Score: 0.860248327255249
# - Toponym: North Carolina
#   Resolved Location: North Carolina, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.50069, -80.00032)
#   Score: 0.9225319027900696
# - Toponym: Arizona
#   Resolved Location: Arizona, United States
#   Feature Type: first-order administrative division
#   Coordinates: (34.5003, -111.50098)
#   Score: 0.909669041633606
# - Toponym: Olney
#   Resolved Location: Olney, United States
#   Feature Type: populated place
#   Coordinates: (33.37066, -98.75284)
#   Score: 0.5339304208755493
# - Toponym: Texas
#   Resolved Location: Texas, United States
#   Feature Type: first-order administrative division
#   Coordinates: (31.25044, -99.25061)
#   Score: 0.8750443458557129
# - Toponym: Vancouver
#   Resolved Location: Vancouver, Canada
#   Feature Type: populated place
#   Coordinates: (49.24966, -123.11934)
#   Score: 0.6004482507705688
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: capital of a political entity
#   Coordinates: (38.89511, -77.03637)
#   Score: 0.7568554878234863
# - Toponym: Haines City
#   Resolved Location: Haines City, United States
#   Feature Type: populated place
#   Coordinates: (28.1145, -81.62009)
#   Score: 0.4935619831085205
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.9049035310745239
# - Toponym: Midland
#   Resolved Location: Midland, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (31.99735, -102.07791)
#   Score: 0.757347583770752
# - Toponym: Michigan
#   Resolved Location: Michigan, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.25029, -85.50033)
#   Score: 0.8741403818130493
# - Toponym: Jackson County
#   Resolved Location: Jackson County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (28.95424, -96.57768)
#   Score: 0.7470277547836304
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.9185383319854736
# - Toponym: Syracuse
#   Resolved Location: Syracuse, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (43.04812, -76.14742)
#   Score: 0.5956772565841675
# - Toponym: Indiana
#   Resolved Location: Indiana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -86.25027)
#   Score: 0.8590065240859985
# - Toponym: Oil City
#   Resolved Location: Oil City, United States
#   Feature Type: populated place
#   Coordinates: (43.61086, -84.58834)
#   Score: 0.5356157422065735
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.8853890895843506
# - Toponym: Grand Blanc
#   Resolved Location: Grand Blanc, United States
#   Feature Type: populated place
#   Coordinates: (42.92753, -83.62995)
#   Score: 0.5289309024810791
# - Toponym: Michigan
#   Resolved Location: Michigan, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.25029, -85.50033)
#   Score: 0.8961371779441833
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8508854508399963
# - Toponym: Scottsboro
#   Resolved Location: Scottsboro, United States
#   Feature Type: populated place
#   Coordinates: (36.21061, -86.92778)
#   Score: 0.5406173467636108
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8453167676925659
# - Toponym: Greenville
#   Resolved Location: Greeneville, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (36.16316, -82.83099)
#   Score: 0.6750562191009521
# - Toponym: South Carolina
#   Resolved Location: South Carolina, United States
#   Feature Type: first-order administrative division
#   Coordinates: (34.00043, -81.00009)
#   Score: 0.7540990114212036
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8719660639762878
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.4957817792892456
# - Toponym: St. David
#   Resolved Location: Cape St. David, Canada
#   Feature Type: cape
#   Coordinates: (63.96728, -64.61387)
#   Score: 0.4625002443790436
# - Toponym: Arizona
#   Resolved Location: Arizona, United States
#   Feature Type: first-order administrative division
#   Coordinates: (34.5003, -111.50098)
#   Score: 0.8911535739898682
# - Toponym: Telly City
# Location could not be resolved.
# - Toponym: Indiana
#   Resolved Location: Indiana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -86.25027)
#   Score: 0.8590065240859985
# - Toponym: Knoxville
#   Resolved Location: Knoxville, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (35.96064, -83.92074)
#   Score: 0.735445499420166
# - Toponym: Tennessee
#   Resolved Location: Tennessee, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.75035, -86.25027)
#   Score: 0.8836447596549988
# - Toponym: New Hampshire
#   Resolved Location: New Hampshire, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.66702, -71.4998)
#   Score: 0.8786911368370056
# - Toponym: New Jersey
#   Resolved Location: New Jersey, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.16706, -74.49987)
#   Score: 0.897379994392395
# - Toponym: Omak
#   Resolved Location: Omak, United States
#   Feature Type: populated place
#   Coordinates: (48.41099, -119.52755)
#   Score: 0.46478480100631714
# - Toponym: Washington
#   Resolved Location: Washington, United States
#   Feature Type: capital of a political entity
#   Coordinates: (38.89511, -77.03637)
#   Score: 0.7671415209770203
# - Toponym: Buckland
#   Resolved Location: Buckland, United States
#   Feature Type: populated place
#   Coordinates: (41.79621, -72.55064)
#   Score: 0.6579186916351318
# - Toponym: Mass
#   Resolved Location: Massachusetts, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.36565, -71.10832)
#   Score: 0.8715267777442932
# - Toponym: Westport
#   Resolved Location: Westport, United States
#   Feature Type: populated place
#   Coordinates: (41.14149, -73.3579)
#   Score: 0.6257228851318359
# - Toponym: Massachusetts
#   Resolved Location: Massachusetts, United States
#   Feature Type: first-order administrative division
#   Coordinates: (42.36565, -71.10832)
#   Score: 0.8715267777442932
# - Toponym: St. Anthony
#   Resolved Location: Saint Anthony, United States
#   Feature Type: populated place
#   Coordinates: (45.68663, -94.61223)
#   Score: 0.5959010124206543
# - Toponym: Idaho
#   Resolved Location: Idaho, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.5002, -114.25118)
#   Score: 0.8810136318206787
# - Toponym: New Hampshire
#   Resolved Location: New Hampshire, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.66702, -71.4998)
#   Score: 0.9473360180854797
# - Toponym: New Hampshire
#   Resolved Location: New Hampshire, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.66702, -71.4998)
#   Score: 0.9473360180854797
# - Toponym: Whyoming
# Location could not be resolved.
# - Toponym: Hillsboro
#   Resolved Location: Hillsborough, United States
#   Feature Type: populated place
#   Coordinates: (43.1141, -71.8992)
#   Score: 0.7338374257087708
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.8033778667449951
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.46396884322166443
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.9285991191864014
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.46396884322166443
# - Toponym: Stroudsburg
#   Resolved Location: Stroudsburg, United States
#   Feature Type: populated place
#   Coordinates: (40.98676, -75.19462)
#   Score: 0.35370194911956787
# - Toponym: Pennsylvania
#   Resolved Location: Pennsylvania, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.8, -77.7)
#   Score: 0.9431992173194885
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.9285991191864014
# - Toponym: Shippensburg
#   Resolved Location: Shippensburg, United States
#   Feature Type: populated place
#   Coordinates: (40.05065, -77.52026)
#   Score: 0.508743405342102
# - Toponym: Campbell County
#   Resolved Location: Campbell County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (37.20564, -79.09635)
#   Score: 0.5489304661750793
# - Toponym: Wyoming
#   Resolved Location: Wyoming, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00024, -107.5009)
#   Score: 0.8807884454727173
# - Toponym: Washington County
#   Resolved Location: Washington County, United States
#   Feature Type: second-order administrative division
#   Coordinates: (39.45532, -81.49525)
#   Score: 0.5606117844581604
# - Toponym: Alabama
#   Resolved Location: Alabama, United States
#   Feature Type: first-order administrative division
#   Coordinates: (32.75041, -86.75026)
#   Score: 0.8134168982505798
# - Toponym: Anaheim
#   Resolved Location: Anaheim, United States
#   Feature Type: populated place
#   Coordinates: (33.83529, -117.9145)
#   Score: 0.6249650120735168
# - Toponym: California
#   Resolved Location: California, United States
#   Feature Type: first-order administrative division
#   Coordinates: (37.25022, -119.75126)
#   Score: 0.8673893809318542
# - Toponym: Drake
#   Resolved Location: Moats, United States
#   Feature Type: populated place
#   Coordinates: (41.33172, -84.52578)
#   Score: 0.5527836084365845
# - Toponym: North Carolina
#   Resolved Location: North Carolina, United States
#   Feature Type: first-order administrative division
#   Coordinates: (35.50069, -80.00032)
#   Score: 0.8015398979187012
# - Toponym: Rochester
#   Resolved Location: Rochester, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (44.02163, -92.4699)
#   Score: 0.6642777919769287
# - Toponym: Michigan
#   Resolved Location: Michigan, United States
#   Feature Type: first-order administrative division
#   Coordinates: (44.25029, -85.50033)
#   Score: 0.8863641023635864
# - Toponym: Levittown
#   Resolved Location: Willingboro, United States
#   Feature Type: populated place
#   Coordinates: (40.02789, -74.86905)
#   Score: 0.48100778460502625
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.882339358329773
# - Toponym: North Jackson
#   Resolved Location: North Jackson Station, United States
#   Feature Type: None
#   Coordinates: (41.10006, -80.87175)
#   Score: 0.527795135974884
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8843542337417603
# - Toponym: Lakeland
#   Resolved Location: Lakeland, United States
#   Feature Type: populated place
#   Coordinates: (28.03947, -81.9498)
#   Score: 0.5751880407333374
# - Toponym: Florida
#   Resolved Location: Florida, United States
#   Feature Type: first-order administrative division
#   Coordinates: (28.75054, -82.5001)
#   Score: 0.8879431486129761
# - Toponym: Washington Park High School
#   Resolved Location: Park High School, United States
#   Feature Type: school
#   Coordinates: (42.71785, -87.80462)
#   Score: 0.4871104657649994
# - Toponym: Kentucky
#   Resolved Location: Kentucky, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.20042, -84.87762)
#   Score: 0.9013223052024841
# - Toponym: Caspar
#   Resolved Location: Caspar, United States
#   Feature Type: populated place
#   Coordinates: (39.3635, -123.81585)
#   Score: 0.4788997769355774
# - Toponym: Wyoming
#   Resolved Location: Wyoming, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00024, -107.5009)
#   Score: 0.8978346586227417
# - Toponym: Bozeman
#   Resolved Location: Bozeman, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (45.67965, -111.03856)
#   Score: 0.5216835141181946
# - Toponym: Montana
#   Resolved Location: Montana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.00025, -109.75102)
#   Score: 0.861629843711853
# - Toponym: Pagosa Springs
#   Resolved Location: Pagosa Springs, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (37.26945, -107.00976)
#   Score: 0.5721980333328247
# - Toponym: Colorado
#   Resolved Location: Colorado, United States
#   Feature Type: first-order administrative division
#   Coordinates: (39.00027, -105.50083)
#   Score: 0.9291817545890808
# - Toponym: Eden Valley
#   Resolved Location: Eden Valley, United States
#   Feature Type: populated place
#   Coordinates: (45.32607, -94.54611)
#   Score: 0.5590431690216064
# - Toponym: Minnesota
#   Resolved Location: Minnesota, United States
#   Feature Type: first-order administrative division
#   Coordinates: (46.25024, -94.25055)
#   Score: 0.8640209436416626
# - Toponym: New York
#   Resolved Location: New York, United States
#   Feature Type: first-order administrative division
#   Coordinates: (43.00035, -75.4999)
#   Score: 0.8075512647628784
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.3764733672142029
# - Toponym: Warren
#   Resolved Location: Warren, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (48.19664, -96.77284)
#   Score: 0.6177221536636353
# - Toponym: Indiana
#   Resolved Location: Indiana, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -86.25027)
#   Score: 0.8635756969451904
# - Toponym: Waukegan
#   Resolved Location: Waukegan, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (42.36363, -87.84479)
#   Score: 0.7276006937026978
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.8916767835617065
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.37647345662117004
# - Toponym: Kansas City
#   Resolved Location: Kansas City, United States
#   Feature Type: populated place
#   Coordinates: (39.09973, -94.57857)
#   Score: 0.5821685194969177
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.9126454591751099
# - Toponym: Missouri
#   Resolved Location: Missouri, United States
#   Feature Type: first-order administrative division
#   Coordinates: (38.25031, -92.50046)
#   Score: 0.9126454591751099
# - Toponym: Waukegan
#   Resolved Location: Waukegan, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (42.36363, -87.84479)
#   Score: 0.7827153205871582
# - Toponym: Illinois
#   Resolved Location: Illinois, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.00032, -89.25037)
#   Score: 0.9224255084991455
# - Toponym: School District
#   Resolved Location: District School, United States
#   Feature Type: school
#   Coordinates: (43.23228, -78.90893)
#   Score: 0.4981037974357605
# - Toponym: Minot
#   Resolved Location: Minot, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (48.23251, -101.29627)
#   Score: 0.6656807661056519
# - Toponym: North Dakota
#   Resolved Location: North Dakota, United States
#   Feature Type: first-order administrative division
#   Coordinates: (47.50027, -100.00068)
#   Score: 0.897624671459198
# - Toponym: Xenia
#   Resolved Location: Xenia, United States
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (39.68478, -83.92965)
#   Score: 0.6727229952812195
# - Toponym: Ohio
#   Resolved Location: Ohio, United States
#   Feature Type: first-order administrative division
#   Coordinates: (40.25034, -83.00018)
#   Score: 0.8994947671890259
#
# Filename: bandbook.txt
# Number of Toponyms: 22
# - Toponym: Jr.
#   Resolved Location: Clyde Kerr Jr. (residence), United States
#   Feature Type: house(s)
#   Coordinates: (29.96992, -90.07923)
#   Score: 0.5341746211051941
# - Toponym: Baldwin
#   Resolved Location: Baldwin, United States
#   Feature Type: populated place
#   Coordinates: (40.33813, -79.97894)
#   Score: 0.6195173859596252
# - Toponym: Huxley
#   Resolved Location: Huxley, United Kingdom
#   Feature Type: populated place
#   Coordinates: (53.14812, -2.7311)
#   Score: 0.5245513916015625
# - Toponym: K Vonnegut
# Location could not be resolved.
# - Toponym: Choirboys
# Location could not be resolved.
# - Toponym: Deep Valley
#   Resolved Location: Deep Valley, United States
#   Feature Type: populated place
#   Coordinates: (39.7548, -80.46952)
#   Score: 0.44575202465057373
# - Toponym: Puerto Rican
#   Resolved Location: Puerto Rican High School, United States
#   Feature Type: school
#   Coordinates: (41.91225, -87.68589)
#   Score: 0.5502822399139404
# - Toponym: Baldwin
#   Resolved Location: Baldwin, United States
#   Feature Type: populated place
#   Coordinates: (40.33813, -79.97894)
#   Score: 0.6335034370422363
# - Toponym: J. Steibeck
# Location could not be resolved.
# - Toponym: Rollin
#   Resolved Location: Rollin, United States
#   Feature Type: None
#   Coordinates: (41.2618, -123.11726)
#   Score: 0.46946847438812256
# - Toponym: K Gilden
# Location could not be resolved.
# - Toponym: Cold Blood
# Location could not be resolved.
# - Toponym: Neufeld
#   Resolved Location: Neufeld, Germany
#   Feature Type: populated place
#   Coordinates: (53.31454, 12.86914)
#   Score: 0.5242959260940552
# - Toponym: Bradbury
#   Resolved Location: Bradbury, United States
#   Feature Type: populated place
#   Coordinates: (34.14695, -117.9709)
#   Score: 0.5656689405441284
# - Toponym: Solzhenitayn
# Location could not be resolved.
# - Toponym: K Kesey
# Location could not be resolved.
# - Toponym: Bradford
#   Resolved Location: Bradford, United Kingdom
#   Feature Type: seat of a second-order administrative division
#   Coordinates: (53.79391, -1.75206)
#   Score: 0.6267225742340088
# - Toponym: D. Jenkins
# Location could not be resolved.
# - Toponym: Knowles
#   Resolved Location: Knowles, United States
#   Feature Type: populated place
#   Coordinates: (37.21995, -119.87405)
#   Score: 0.546363353729248
# - Toponym: W Faulkner
# Location could not be resolved.
# - Toponym: Baldwin
#   Resolved Location: Baldwin, United States
#   Feature Type: populated place
#   Coordinates: (40.33813, -79.97894)
#   Score: 0.5987285375595093
# - Toponym: K Vonnegut
# Location could not be resolved.

# %% [markdown]
# ---
#
# ## 3. Visualizing Locations on a Map <a name="visualizing-locations-on-a-map"></a>
#
# Visualizing the extracted locations on a map can provide valuable insights.
#
# ### 3.1 Preparing Data for Mapping <a name="preparing-data-for-mapping"></a>
#
# **Objective:** Extract coordinates of resolved locations and prepare them for mapping.
#
# **Instructions:**
#
# - Extract the coordinates of all resolved locations from the parsed documents.
# - Prepare a list of tuples containing the latitude and longitude of each location.
#   - The expected structure is a list of tuples: `[(latitude1, longitude1), (latitude2, longitude2), ...]`
#
# **Your Code:**
#
# *(Write your code in the cell below.)*

# %%
# Your code here

# %% [markdown]
# ### 3.2 Map the Geoparsed Locations <a name="task-map-the-geoparsed-locations"></a>
#
# **Objective:** Create an interactive map displaying the resolved locations.
#
# **Instructions:**
#
# - Use the provided function `create_map` to generate a map with markers for each location.
#
# **Prepared Code:**

# %%
import folium

def create_map(coordinates):
    # Initialize map
    m = folium.Map()

    # Add markers to the map
    for coord in coordinates:
        folium.Marker(
            location=[coord[0], coord[1]],
        ).add_to(m)

    return m

# Create and display the map
m = create_map(coordinates)  # Replace 'coordinates' with your variable
m

# %% [markdown]
# ---
#
# ## 4. Additional Exercises <a name="additional-exercises"></a>
#
# ### 4.1 Handling Ambiguous Toponyms <a name="handling-ambiguous-toponyms"></a>
#
# **Objective:** Explore how contextual clues affect toponym disambiguation.
#
# Ambiguous toponyms like "Paris" can refer to multiple places around the world. Geoparser uses contextual clues to disambiguate such toponyms.
#
# **Instructions:**
#
# - Parse the provided example texts.
#
# **Analyze the Results:**
#
# - Qualitatively assess how Geoparser resolves the toponym "Paris" in each case.
# - How does the context influence the resolution?
# - What limitations can you observe?
#
# **Example Texts:**

# %%
ambiguous_texts = [
    "The Eiffel Tower is one of the most famous landmarks in Paris.",
    "After passing through Paris, we drove all the way to Dallas.",
    "I have friends living in Paris, Ontario, who love to kayak on the Grand River.",
    "The Governor of Texas visited Paris for the 2024 Summer Olympics."
    "There are 34 places named Paris in the United States. Examples include Paris, Arkansas, Paris, Texas and Paris, Wisconsin."
]

# %% [markdown]
# **Your Code:**
#
# *(Write your code in the cell below.)*

# %%
# Your code here

# %% [markdown]
# ---
#
# ### 4.2 Filtering Candidate Locations <a name="filtering-candidate-locations"></a>
#
# **Objective:** Use filters to restrict candidate locations during parsing.
#
# In some cases, you might want to restrict the candidate locations considered during geoparsing. This can be done by applying filters during candidate generation.
#
# **Instructions:**
#
# - Use the ambiguous texts from the previous exercise.
# - Apply a filter during parsing so that it only considers locations in France.
#
# **Note:** In practice, filters should only be used if you are absolutely sure about the scope of location references. Generally, using no filter is the recommended way to go.
#
#
# **Your Code:**
#
# *(Write your code in the cell below.)*

# %%
# Your code here

# %% [markdown]
# ---
#
# ## 5. Bonus Exercise: Integrating Geoparser into a Workflow <a name="bonus-exercise"></a>
#
# In this bonus exercise, we'll see how Geoparser can be integrated into a real-world workflow. We'll fetch news article headlines based on a keyword, parse them with Geoparser, and visualize the extracted locations on a map.
#
# ### 5.1 Fetching News Articles <a name="fetching-news-articles"></a>
#
# **Objective:** Fetch news article headlines from Google News RSS feed based on a keyword.
#
# **Instructions:**
#
# - Choose a keyword to search for news articles (e.g., "Technology", "Climate Change", etc.).
# - Use the `fetch_news_articles` function to get the article titles.
#
# **Prepared Code:**

# %%
import requests
import xml.etree.ElementTree as ET

def fetch_news_articles(keyword):
    url = f"https://news.google.com/rss/search?q={keyword}"
    response = requests.get(url)

    # Parse the RSS feed
    root = ET.fromstring(response.content)

    # Extract article titles
    articles = []
    for item in root.findall(".//item"):
        title = item.find("title").text
        articles.append(title)

    return articles

# Choose a keyword
keyword = "Your Keyword Here"  # Replace with your chosen keyword

# Fetch articles
articles = fetch_news_articles(keyword)

# %% [markdown]
# ### 5.2 Parse the Articles with Geoparser <a name="task-parse-articles"></a>
#
# **Objective:** Use Geoparser to parse the list of article titles.
#
# **Instructions:**
#
# - Use Geoparser to parse the `articles`.
# - Store the parsed documents for further analysis.
#
# **Your Code:**
#
# *(Write your code in the cell below.)*

# %%
# Your code here

# %% [markdown]
# ### 5.3 Collecting and Analyzing Toponym Data <a name="collecting-toponym-data"></a>
#
# **Objective:** Collect toponym data from the parsed article headlines.
#
# **Instructions:**
#
# - Iterate over the parsed documents.
# - For each toponym in a document:
#   - Access the resolved location information.
#   - Group the results by location and format the data in a structure suitable for mapping.
#
# **Hints:**
#
# - We want to create a data structure `toponym_data` that is a dictionary where:
#   - The key is a tuple `(location_name, latitude, longitude)`, representing a referenced location.
#   - The value is another dictionary with:
#     - `"count"`: number of times the location is referenced.
#     - `"sentences"`: list of sentences (article titles) where the location is referenced.
# - We have initialized a `defaultdict` named `toponym_data` in the code cell below. You can add data to this `defaultdict` like this:
#   - To up the counter for a specific location:
#     - `toponym_data[("Zurich", 47.3769, 8.5417)]["count"] += 1`
#   - To add a sentence:
#     - `toponym_data[("Zurich", 47.3769, 8.5417)]["sentences"].append("Zurich is a financial hub.")`
#
# **Your Code:**
#
# *(Write your code in the cell below.)*

# %%
from collections import defaultdict

# Initialize toponym_data
toponym_data = defaultdict(lambda: {"count": 0, "sentences": []})

# Collect toponym data
# Your code here

# %% [markdown]
# ### 5.4 Visualizing the Locations on a Map <a name="visualizing-news-locations"></a>
#
# **Objective:** Create a map with the collected location data.
#
# **Instructions:**
#
# - Use the `create_news_map` function to create a map using your `toponym_data`.
#
# **Prepared Code:**

# %%
import folium

def create_news_map(toponym_data):
    # Initialize map centered at global coordinates
    m = folium.Map()

    for (name, lat, lon), data in toponym_data.items():
        # Prepare popup content
        sentences_html = "<br><br>".join(data["sentences"])
        popup_html = f"""
        <strong>{name}</strong><br><br>{sentences_html}
        """

        folium.CircleMarker(
            location=[lat, lon],
            radius=5 + data["count"] * 2,  # Size scales with the number of occurrences
            popup=folium.Popup(popup_html, max_width=300),
            color='crimson',
            fill=True,
            fill_color='crimson'
        ).add_to(m)
    return m

# Create and display the map
m = create_news_map(toponym_data)
m
